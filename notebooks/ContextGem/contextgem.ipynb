# %%
# %pip install -qU contextgem

# %%
# Quick Start Example - Extracting anomalies from a document, with source references and justifications

import os

from contextgem import Document, DocumentLLM, StringConcept

# Sample document text (shortened for brevity)
doc = Document(
    raw_text=(
        "Consultancy Agreement\n"
        "This agreement between Company A (Supplier) and Company B (Customer)...\n"
        "The term of the agreement is 1 year from the Effective Date...\n"
        "The Supplier shall provide consultancy services as described in Annex 2...\n"
        "The Customer shall pay the Supplier within 30 calendar days of receiving an invoice...\n"
        "The purple elephant danced gracefully on the moon while eating ice cream.\n"  # 💎 anomaly
        "This agreement is governed by the laws of Norway...\n"
    ),
)

# Attach a document-level concept
doc.concepts = [
    StringConcept(
        name="Anomalies",  # in longer contexts, this concept is hard to capture with RAG
        description="Anomalies in the document",
        add_references=True,
        reference_depth="sentences",
        add_justifications=True,
        justification_depth="brief",
        # see the docs for more configuration options
    )
    # add more concepts to the document, if needed
    # see the docs for available concepts: StringConcept, JsonObjectConcept, etc.
]
# Or use `doc.add_concepts([...])`

# Define an LLM for extracting information from the document
llm = DocumentLLM(
    model="google/gemini-1.5-flash",  # or another provider/LLM
    api_key=os.environ.get(
        "GOOGLE_API_KEY"
    ),  # your API key for the LLM provider
    # see the docs for more configuration options
)

# Extract information from the document
doc = llm.extract_all(doc)  # or use async version `await llm.extract_all_async(doc)`

# Access extracted information in the document object
print(
    doc.concepts[0].extracted_items
)  # extracted items with references & justifications
# or `doc.get_concept_by_name("Anomalies").extracted_items`
# Out:
# [contextgem] 2025-05-08 23:14:08.054 | INFO    | Text is being split into paragraphs, as no custom paragraphs were provided...
# [contextgem] 2025-05-08 23:14:08.057 | INFO    | Paragraphs are being split into sentences...
# [contextgem] 2025-05-08 23:14:08.058 | INFO    | Loading SaT model sat-3l-sm...
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/615 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.10M [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[2], line 8
#       5 from contextgem import Document, DocumentLLM, StringConcept
#       7 # Sample document text (shortened for brevity)
# ----> 8 doc = Document(
#       9     raw_text=(
#      10         "Consultancy Agreement\n"
#      11         "This agreement between Company A (Supplier) and Company B (Customer)...\n"
#      12         "The term of the agreement is 1 year from the Effective Date...\n"
#      13         "The Supplier shall provide consultancy services as described in Annex 2...\n"
#      14         "The Customer shall pay the Supplier within 30 calendar days of receiving an invoice...\n"
#      15         "The purple elephant danced gracefully on the moon while eating ice cream.\n"  # 💎 anomaly
#      16         "This agreement is governed by the laws of Norway...\n"
#      17     ),
#      18 )
#      20 # Attach a document-level concept
#      21 doc.concepts = [
#      22     StringConcept(
#      23         name="Anomalies",  # in longer contexts, this concept is hard to capture with RAG
#    (...)
#      32     # see the docs for available concepts: StringConcept, JsonObjectConcept, etc.
#      33 ]
#
#     [... skipping hidden 1 frame]
#
# File ~/CODE/multimodal-rag-baseline/env/lib/python3.10/site-packages/pydantic/_internal/_model_construction.py:126, in ModelMetaclass.__new__.<locals>.wrapped_model_post_init(self, context)
#     122 """We need to both initialize private attributes and call the user-defined model_post_init
#     123 method.
#     124 """
#     125 init_private_attributes(self, context)
# --> 126 original_model_post_init(self, context)
#
# File ~/CODE/multimodal-rag-baseline/env/lib/python3.10/site-packages/pydantic/_internal/_model_construction.py:126, in ModelMetaclass.__new__.<locals>.wrapped_model_post_init(self, context)
#     122 """We need to both initialize private attributes and call the user-defined model_post_init
#     123 method.
#     124 """
#     125 init_private_attributes(self, context)
# --> 126 original_model_post_init(self, context)
#
#     [... skipping similar frames: ModelMetaclass.__new__.<locals>.wrapped_model_post_init at line 126 (2 times)]
#
# File ~/CODE/multimodal-rag-baseline/env/lib/python3.10/site-packages/pydantic/_internal/_model_construction.py:126, in ModelMetaclass.__new__.<locals>.wrapped_model_post_init(self, context)
#     122 """We need to both initialize private attributes and call the user-defined model_post_init
#     123 method.
#     124 """
#     125 init_private_attributes(self, context)
# --> 126 original_model_post_init(self, context)
#
# File ~/CODE/multimodal-rag-baseline/env/lib/python3.10/site-packages/contextgem/internal/base/mixins.py:56, in _PostInitCollectorMixin.model_post_init(self, _PostInitCollectorMixin__context)
#      54 # Pydantic-specific
#      55 for func in self.__class__.__post_init_methods__:
# ---> 56     func(self, __context)
#
# File ~/CODE/multimodal-rag-baseline/env/lib/python3.10/site-packages/contextgem/internal/decorators.py:103, in _timer_decorator.<locals>.outer_wrapper.<locals>.sync_wrapper(*args, **kwargs)
#     100 @wraps(func)
#     101 def sync_wrapper(*args: P.args, **kwargs: P.kwargs) -> Any:
#     102     start_time = timeit.default_timer()
# --> 103     result = func(*args, **kwargs)
#     104     log_end(start_time)
#     105     return result
#
# File ~/CODE/multimodal-rag-baseline/env/lib/python3.10/site-packages/contextgem/public/documents.py:143, in Document._post_init(self, _Document__context)
#     137 @_timer_decorator(
#     138     "Document initialization",
#     139 )
#     140 @_post_init_method
#     141 def _post_init(self, __context):
#     142     self._set_text_from_paras()
# --> 143     self._segment_paras_and_sents()
#
# File ~/CODE/multimodal-rag-baseline/env/lib/python3.10/site-packages/contextgem/public/documents.py:231, in Document._segment_paras_and_sents(self)
#     226 if any(i.sentences for i in self.paragraphs):
#     227     warnings.warn(
#     228         "Some paragraphs already have sentences. "
#     229         "These will be used `as is`."
#     230     )
# --> 231 split_sents_for_paras = _get_sat_model(self.sat_model_id).split(
#     232     [p.raw_text for p in self.paragraphs]
#     233 )
#     234 for paragraph, sent_group in zip(
#     235     self.paragraphs, split_sents_for_paras
#     236 ):
#     237     if not paragraph.sentences:
#     238         # Filter out empty sents, if any
#
# File ~/CODE/multimodal-rag-baseline/env/lib/python3.10/site-packages/contextgem/internal/utils.py:543, in _get_sat_model(model_id)
#     533 """
#     534 Retrieves and caches a SaT model to be used for paragraphs and sentence segmentation.
#     535
#    (...)
#     540     An instance of the SaT model associated with the given `model_id`.
#     541 """
#     542 logger.info(f"Loading SaT model {model_id}...")
# --> 543 model = SaT(model_id)
#     544 logger.info(f"SaT model {model_id} loaded.")
#     545 return model
#
# File ~/CODE/multimodal-rag-baseline/env/lib/python3.10/site-packages/wtpsplit/__init__.py:522, in SaT.__init__(self, model_name_or_model, tokenizer_name_or_path, from_pretrained_kwargs, ort_providers, ort_kwargs, style_or_domain, language, lora_path, hub_prefix)
#     519     except ModuleNotFoundError:
#     520         raise ValueError("Please install `torch` to use WtP with a PyTorch model.")
# --> 522     import wtpsplit.models  # noqa
#     524     self.model = PyTorchWrapper(
#     525         AutoModelForTokenClassification.from_pretrained(
#     526             model_name_to_fetch, **(from_pretrained_kwargs or {})
#     527         )
#     528     )
#     529 # LoRA LOADING
#
# File ~/CODE/multimodal-rag-baseline/env/lib/python3.10/site-packages/wtpsplit/models.py:13
#       8 from transformers import AutoModel, AutoModelForTokenClassification
#       9 from transformers.modeling_outputs import (
#      10     BaseModelOutputWithPoolingAndCrossAttentions,
#      11     BaseModelOutputWithPastAndCrossAttentions,
#      12 )
# ---> 13 from transformers.modeling_utils import ModuleUtilsMixin
#      14 from transformers.models.bert.modeling_bert import BertEncoder, BertForTokenClassification, BertModel, BertPooler
#      15 from transformers.models.canine.modeling_canine import (
#      16     _PRIMES,
#      17     ACT2FN,
#    (...)
#      33     TokenClassifierOutput,
#      34 )
#
# File ~/CODE/multimodal-rag-baseline/env/lib/python3.10/site-packages/transformers/modeling_utils.py:51
#      49 from .integrations.flex_attention import flex_attention_forward
#      50 from .integrations.sdpa_attention import sdpa_attention_forward
# ---> 51 from .loss.loss_utils import LOSS_MAPPING
#      52 from .pytorch_utils import (  # noqa: F401
#      53     Conv1D,
#      54     apply_chunking_to_forward,
#    (...)
#      60     translate_to_torch_parallel_style,
#      61 )
#      62 from .quantizers import AutoHfQuantizer, HfQuantizer
#
# File ~/CODE/multimodal-rag-baseline/env/lib/python3.10/site-packages/transformers/loss/loss_utils.py:19
#      16 import torch.nn as nn
#      17 from torch.nn import BCEWithLogitsLoss, MSELoss
# ---> 19 from .loss_deformable_detr import DeformableDetrForObjectDetectionLoss, DeformableDetrForSegmentationLoss
#      20 from .loss_for_object_detection import ForObjectDetectionLoss, ForSegmentationLoss
#      21 from .loss_rt_detr import RTDetrForObjectDetectionLoss
#
# File ~/CODE/multimodal-rag-baseline/env/lib/python3.10/site-packages/transformers/loss/loss_deformable_detr.py:4
#       1 import torch
#       2 import torch.nn as nn
# ----> 4 from ..image_transforms import center_to_corners_format
#       5 from ..utils import is_scipy_available
#       6 from .loss_for_object_detection import (
#       7     HungarianMatcher,
#       8     ImageLoss,
#    (...)
#      11     sigmoid_focal_loss,
#      12 )
#
# File ~/CODE/multimodal-rag-baseline/env/lib/python3.10/site-packages/transformers/image_transforms.py:22
#      18 from typing import Iterable, List, Optional, Tuple, Union
#      20 import numpy as np
# ---> 22 from .image_utils import (
#      23     ChannelDimension,
#      24     ImageInput,
#      25     get_channel_dimension_axis,
#      26     get_image_size,
#      27     infer_channel_dimension_format,
#      28 )
#      29 from .utils import ExplicitEnum, TensorType, is_jax_tensor, is_tf_tensor, is_torch_tensor
#      30 from .utils.import_utils import (
#      31     is_flax_available,
#      32     is_tf_available,
#    (...)
#      37     requires_backends,
#      38 )
#
# File ~/CODE/multimodal-rag-baseline/env/lib/python3.10/site-packages/transformers/image_utils.py:59
#      56         PILImageResampling = PIL.Image
#      58     if is_torchvision_available():
# ---> 59         from torchvision.transforms import InterpolationMode
#      61         pil_torch_interpolation_mapping = {
#      62             PILImageResampling.NEAREST: InterpolationMode.NEAREST,
#      63             PILImageResampling.BOX: InterpolationMode.BOX,
#    (...)
#      67             PILImageResampling.LANCZOS: InterpolationMode.LANCZOS,
#      68         }
#      71 if TYPE_CHECKING:
#
# File ~/CODE/multimodal-rag-baseline/env/lib/python3.10/site-packages/torchvision/__init__.py:6
#       3 from modulefinder import Module
#       5 import torch
# ----> 6 from torchvision import _meta_registrations, datasets, io, models, ops, transforms, utils
#       8 from .extension import _HAS_OPS
#      10 try:
#
# File ~/CODE/multimodal-rag-baseline/env/lib/python3.10/site-packages/torchvision/_meta_registrations.py:164
#     153     torch._check(
#     154         grad.dtype == rois.dtype,
#     155         lambda: (
#    (...)
#     158         ),
#     159     )
#     160     return grad.new_empty((batch_size, channels, height, width))
#     163 @torch._custom_ops.impl_abstract("torchvision::nms")
# --> 164 def meta_nms(dets, scores, iou_threshold):
#     165     torch._check(dets.dim() == 2, lambda: f"boxes should be a 2d tensor, got {dets.dim()}D")
#     166     torch._check(dets.size(1) == 4, lambda: f"boxes should have 4 elements in dimension 1, got {dets.size(1)}")
#
# File ~/CODE/multimodal-rag-baseline/env/lib/python3.10/site-packages/torch/library.py:1023, in register_fake.<locals>.register(func)
#    1021 else:
#    1022     use_lib = lib
# -> 1023 use_lib._register_fake(op_name, func, _stacklevel=stacklevel + 1)
#    1024 return func
#
# File ~/CODE/multimodal-rag-baseline/env/lib/python3.10/site-packages/torch/library.py:214, in Library._register_fake(self, op_name, fn, _stacklevel)
#     211 else:
#     212     func_to_register = fn
# --> 214 handle = entry.fake_impl.register(func_to_register, source)
#     215 self._registration_handles.append(handle)
#
# File ~/CODE/multimodal-rag-baseline/env/lib/python3.10/site-packages/torch/_library/fake_impl.py:31, in FakeImplHolder.register(self, func, source)
#      25 if self.kernel is not None:
#      26     raise RuntimeError(
#      27         f"register_fake(...): the operator {self.qualname} "
#      28         f"already has an fake impl registered at "
#      29         f"{self.kernel.source}."
#      30     )
# ---> 31 if torch._C._dispatch_has_kernel_for_dispatch_key(self.qualname, "Meta"):
#      32     raise RuntimeError(
#      33         f"register_fake(...): the operator {self.qualname} "
#      34         f"already has an DispatchKey::Meta implementation via a "
#    (...)
#      37         f"register_fake."
#      38     )
#      40 if torch._C._dispatch_has_kernel_for_dispatch_key(
#      41     self.qualname, "CompositeImplicitAutograd"
#      42 ):
#
# RuntimeError: operator torchvision::nms does not exist
