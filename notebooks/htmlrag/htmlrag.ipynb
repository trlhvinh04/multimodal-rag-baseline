# %% [markdown]
# # Load lib

# %%
from htmlrag import clean_html
from htmlrag import EmbedHTMLPruner
from htmlrag import build_block_tree
from htmlrag import GenHTMLPruner
from htmlrag import BM25HTMLPruner
import torch
from transformers import AutoTokenizer
import os

# %% [markdown]
# # Clean HTML

# %%
path = "/kaggle/input/kyanon-data/data_kyanon/datahtml/anhone.html"
html = open(path).read() 

simplified_html = clean_html(html)
print(simplified_html)
# Out:
# <div>
# <div><div>2018 Baseball Hall of Fame balloting</div><div>1 language</div><div>Article<span>Talk<span>Read</span>EditView history</span></div><div>Tools</div><div><div>←<span>20172019</span>→</div><div>2018 Baseball Hall of Fame</div><div>balloting</div><div>   National Baseball   </div><div>Hall of Fame and Museum</div><div>New inductees<span>6</span></div><div>via BBWAA<span>4</span></div><div>via Modern Baseball Era</div><div>Committee</div><div>2</div><div>Total inductees<span>323</span></div><div>Induction date<span>July 29, 2018</span></div><div>Key</div><div></div><div>Elected to the Hall of Fame on this ballot (named</div><div>in <span>bold italics</span>).</div><div></div><div>Elected subsequently, as of 2025 (named in <span>plain</span></div><div>italics<span>).</span></div><div></div><div>Renominated for the <span>2019 BBWAA election<span> by</span></span></div><div>adequate performance on this ballot and has not</div><div>subsequently been eliminated.</div><div>Eliminated from annual BBWAA consideration by</div><div>poor performance or expiration on subsequent</div></div><div>From Wikipedia, the free encyclopedia</div><div><div>(Redirected from <span>Baseball Hall of Fame balloting, 2018</span>)</div><div>Elections to the <span>National Baseball Hall of Fame</span> for 2018</div><div>proceeded according to rules most recently amended in 2016.</div><div>As in the past, the <span>Baseball Writers' Association of America</span></div><div>(BBWAA) voted by mail to select from a ballot of recently</div><div>retired players. The results were announced on January 24,</div><div>2018, with the BBWAA electing <span>Chipper Jones</span>, <span>Vladimir</span></div><div>Guerrero<span>, </span>Jim Thome<span> and <span>Trevor Hoffman<span> to the Hall of Fame.</span></span></span></div><div>Jones and Thome were elected in their first year of eligibility.</div><div>[1]</div><div>The three voting panels that replaced the more broadly</div><div>defined <span>Veterans Committee<span> following a 2010 rules change</span></span></div><div>[2]</div><div>were replaced by a new set of four panels in 2016.</div><div>[3]</div><div> The</div><div>Modern Baseball Era Committee<span> convened on December 10,</span></div><div>2017, to select from a ballot of retired players and non-playing personnel who made their greatest</div><div>contributions to the sport between 1970 and 1987,</div><div>[3]</div><div> with <span>Jack Morris</span> and <span>Alan Trammell<span> elected by this</span></span></div><div>body.</div><div>[4]</div><div> The formal induction ceremony was held at the Hall's facilities in <span>Cooperstown, New York<span>, on July</span></span></div><div>29, 2018.</div><div>[1]</div><div>BBWAA election <span>[<span>edit</span>]</span></div><div>The BBWAA election rules remained identical to</div><div>those that were in effect for the most recent</div><div>elections. The BBWAA voted at the 2016 winter</div><div>meetings to make all Hall of Fame ballots public</div><div>one week after the results were announced,</div><div>effective with this election.</div><div>[5]</div><div> However, the Hall</div><div>rejected the BBWAA's proposal, and ballots remain</div><div>confidential unless individual voters choose to</div><div>reveal them (which is allowed by Hall of Fame</div><div>rules).</div><div>[6]</div><div>DonateCreate accountLog in</div></div></div>
# <div><div>ballots.</div><div></div><div>Eliminated from annual BBWAA consideration by</div><div>poor performance or expiration on this ballot.</div><div>†First time on the BBWAA ballot.</div><div>*</div><div>Eliminated from annual BBWAA consideration by</div><div>poor performance on this ballot (not expiration).</div><div>Chipper Jones</div><div>Another recent rules change, announced in 2015,</div><div>tightened the qualifications for the BBWAA</div><div>electorate. Beginning with the 2016 election,</div><div>eligible voters must not only have 10years of</div><div>continuous BBWAA membership, but also be</div><div>currently active members, or have held active</div><div>status within the 10years prior to the election. A</div><div>BBWAA member who has not been active for more</div><div>than 10years can regain voting status by covering MLB in the year preceding the election.</div><div>[7]</div><div> As a result of</div><div>the new rule, the vote total in 2016 decreased by 109 from the previous year, to 440.</div><div>[8]</div><div>The ballot included two categories of players:</div><div>Candidates from the 2017 ballot who received at least 5% of the vote but were not elected, as long as</div><div>they first appeared on the BBWAA ballot no earlier than 2009.</div><div>Selected individuals, chosen by a screening committee, whose last MLB appearance was in 2012.</div><div>422 ballots were cast, 20 fewer than in 2017. There were 422 ballots cast, with a total of 3570 votes for</div><div>individual players, an average of 8.46 names per ballot—the highest per-ballot average since 1960 (8.51</div><div>votes per ballot).</div><div>Voting results from 2018:</div><div>[9]</div><div>PlayerVotesPercentChangeYear</div><div>Chipper Jones<span>†<span>41097.2%–1st</span></span></div><div>Vladimir Guerrero<span>39292.9%21.2%2nd</span></div><div>Jim Thome<span>†<span>37989.8%–1st</span></span></div><div>Trevor Hoffman<span>33779.9%5.9%3rd</span></div><div>Edgar Martínez<span>29770.4%11.8%9th</span></div><div>Mike Mussina<span>26863.5%11.7%5th</span></div><div>Roger Clemens<span>24257.3%3.2%6th</span></div><div>Barry Bonds<span>23856.4%2.6%6th</span></div><div>Curt Schilling<span>21651.2%6.2%6th</span></div><div>Omar Vizquel<span>†<span>15637.0%–1st</span></span></div><div>Larry Walker<span>14434.1%12.2%8th</span></div><div>Fred McGriff<span>9823.2%1.5%9th</span></div><div>Manny Ramírez<span>9322.0%1.8%2nd</span></div><div>Jeff Kent<span>6114.5%2.2%5th</span></div><div>Gary Sheffield<span>4711.1%2.2%4th</span></div></div>
# <div><div>Vladimir Guerrero</div><div>Jim Thome</div><div>Trevor Hoffman</div><div>Billy Wagner<span>4711.1%0.9%3rd</span></div><div>Scott Rolen<span>†<span>4310.2%–1st</span></span></div><div>Sammy Sosa<span>337.8%0.8%6th</span></div><div>Andruw Jones<span>†<span>317.3%–1st</span></span></div><div>Jamie Moyer<span>†*<span>102.4%–1st</span></span></div><div>Johan Santana<span>†*<span>102.4%–1st</span></span></div><div>Johnny Damon<span>†*<span>81.9%–1st</span></span></div><div>Hideki Matsui<span>†*<span>40.9%–1st</span></span></div><div>Chris Carpenter<span>†*<span>20.5%–1st</span></span></div><div>Kerry Wood<span>†*<span>20.5%–1st</span></span></div><div>Liván Hernández<span>†*<span>10.2%–1st</span></span></div><div>Carlos Lee<span>†*<span>10.2%–1st</span></span></div><div>Orlando Hudson<span>†*<span>00%–1st</span></span></div><div>Aubrey Huff<span>†*<span>00%–1st</span></span></div><div>Jason Isringhausen<span>†*<span>00%–1st</span></span></div><div>Brad Lidge<span>†*<span>00%–1st</span></span></div><div>Kevin Millwood<span>†*<span>00%–1st</span></span></div><div>Carlos Zambrano<span>†*<span>00%–1st</span></span></div><div>Players who were eligible for the first time in 2018 but were <span>not</span> on</div><div>the ballot included <span>Rod Barajas</span>, <span>Miguel Batista</span>, <span>Geoff Blum</span>, <span>Miguel</span></div><div>Cairo<span>, <span>Aaron Cook<span>, </span>Francisco Cordero<span>, </span>Juan Cruz<span>, </span>Brian Fuentes<span>,</span></span></span></div><div>Bill Hall<span>, </span>Willie Harris<span>, </span>Nick Johnson<span>, <span>Adam Kennedy<span>, <span>Rodrigo</span></span></span></span></div><div>López<span>, </span>Mike MacDougal<span>, </span>Guillermo Mota<span>, </span>Will Ohman<span>, </span>Vicente</div><div>Padilla<span>, </span>Carl Pavano<span>, </span>Scott Podsednik<span>, </span>Juan Rivera<span>, </span>J. C. Romero<span>,</span></div><div>Brian Schneider<span>, <span>Ben Sheets</span>, <span>Jeff Suppan</span>, <span>Kip Wells</span>, <span>Dan Wheeler</span></span></div><div>and <span>Jack Wilson</span>.</div><div>Scott Rolen's 10.2% was the lowest first-year vote percentage in</div><div>history for a candidate who was eventually elected by the BBWAA.</div><div>He was voted in on the <span>2023 ballot</span>.</div><div>[10]</div><div>Modern Baseball Era Committee <span>[<span>edit</span>]</span></div><div>On July 23, 2016, the Hall of Fame announced changes to the Era Committee system. The system's</div><div>timeframes were restructured to place a greater emphasis on the modern game, and to reduce the</div></div>
# <div><div>Jack Morris</div><div>Alan Trammell</div><div>frequency at which individuals from the pre-1970 game (including</div><div>Negro league baseball<span> figures) will have their careers reviewed.</span></div><div>[3]</div><div>Considering candidates whose greatest contributions occurred from</div><div>1970 to 1987, the Modern Baseball Era Committee met in 2017 as</div><div>part of the elections for the next calendar year.</div><div>Further information: <span>Veterans Committee §2016 revisions</span></div><div>On November 6, 2017, the Hall announced the 10 candidates to be</div><div>considered when the Modern Baseball Era Committee met at the</div><div>2017 winter meetings near <span>Walt Disney World<span> on December 10, with</span></span></div><div>the voting results announced immediately after the committee</div><div>met.</div><div>[11]</div><div> The cutoff for election and induction remained the standard</div><div>75%, or 12 of 16 votes.</div><div>The committee consisted of the following individuals:</div><div>[4]</div><div>Hall of Famers: <span>George Brett</span>, <span>Rod Carew<span>, <span>Bobby Cox</span>, <span>Dennis</span></span></span></div><div>Eckersley<span>, <span>John Schuerholz</span>, <span>Don Sutton</span>, <span>Dave Winfield</span>, <span>Robin</span></span></div><div>Yount</div><div>Executives: <span>Sandy Alderson<span>, </span>Paul Beeston<span>, </span>Bob Castellini<span>, </span>David</span></div><div>Glass<span>, </span>Bill DeWitt</div><div>Media and historians: <span>Bob Elliott</span>, <span>Steve Hirdt</span>, <span>Jayson Stark</span></div><div>Non-voting committee chair: Jane Forbes Clark (Hall of Fame</div><div>chairman)</div><div>CandidateCategoryVotesPercentRef</div><div>Jack Morris<span>Player1487.5%</span></div><div>[12]</div><div>Alan Trammell<span>Player1381.3%</span></div><div>[12]</div><div>Ted Simmons<span>Player1168.8%</span></div><div>[12]</div><div>Marvin Miller<span>Executive743.8%</span></div><div>[12]</div><div>Steve Garvey<span>Player&lt;7–</span></div><div>[12]</div><div>Tommy John<span>Player&lt;7–</span></div><div>[12]</div><div>Don Mattingly<span>Player&lt;7–</span></div><div>[12]</div><div>Dale Murphy<span>Player&lt;7–</span></div><div>[12]</div><div>Dave Parker<span>Player&lt;7–</span></div><div>[12]</div><div>Luis Tiant<span>Player&lt;7–</span></div><div>[12]</div><div>All candidates except Miller were living when the ballot and voting results were announced. Mattingly,</div><div>Morris, Murphy and Trammell were being considered for the first time; the others had been considered at</div></div>
# <div><div>least once by one of the predecessors to this committee. Garvey, John, Miller, Parker and Simmons were</div><div>most recently considered in 2014 by the former Expansion Era Committee, and Tiant was most recently</div><div>considered by the former Golden Era Committee in 2015. Among players, Simmons was the only candidate</div><div>who was not on the BBWAA ballot for the full 15-year period formerly allowed by Hall rules; he received less</div><div>than 5% when he debuted on the BBWAA ballot in 1994 and thus did not appear on further ballots. The Hall</div><div>changed the eligibility period to 10 years starting with the 2015 election, but Trammell and Mattingly (who</div><div>were then past the new 10-year cutoff) retained their original 15-year eligibility window.</div><div>J. G. Taylor Spink Award <span>[<span>edit</span>]</span></div><div>The <span>J. G. Taylor Spink Award<span> has been presented by the BBWAA at the annual summer induction</span></span></div><div>ceremonies since 1962.</div><div>[13]</div><div> Through 2010, it was awarded during the main induction ceremony, but is now</div><div>given the previous day at the Hall of Fame Awards Presentation. It recognizes a <span>sportswriter</span> "for meritorious</div><div>contributions to baseball writing".</div><div>[14]</div><div> The recipients are not members of the Hall of Fame but are featured in</div><div>a permanent exhibit at the National Baseball Museum.</div><div>The three finalists for the 2018 award were announced during the 2017 <span>All-Star<span> break.</span></span></div><div>[15]</div><div>Sheldon Ocker<span>, </span><span>Akron Beacon-Journal<span> (retired)</span></span></div><div>Jim Reeves, <span>Fort Worth Star-Telegram</span></div><div>Patrick Reusse<span>, </span><span>Star Tribune<span> (Minneapolis)</span></span></div><div>Ocker was announced as the recipient during the 2017 winter meetings on December 12.</div><div>[16]</div><div> He covered the</div><div>Cleveland Indians for more than three decades, serving as Cleveland Indians beat reporter for the <span>Beacon-</span></div><div>Journal<span> from 1981 until his retirement at the end of the 2013 season. Ocker received 168 of the 426 ballots</span></div><div>cast (including two blanks) to Reeves' 143 and Reusse's 113.</div><div>[17]</div><div>Ford C. Frick Award <span>[<span>edit</span>]</span></div><div>Various changes in July 2016 were also made to the annual <span>Ford C. Frick Award<span> elections, presented</span></span></div><div>annually to a preeminent baseball broadcaster since 1978. According to the Hall, the new criteria for</div><div>selection are "Commitment to excellence, quality of broadcasting abilities, reverence within the game,</div><div>popularity with fans, and recognition by peers."</div><div>Additionally, a ballot of eight candidates will now be set, down from 10 in years past. The three ballot slots</div><div>previously determined by fan voting on <span>Facebook</span> will now be filled by a committee of historians.</div><div>A new election cycle has been established, rotating annually between <span>Current Major League Markets</span> (team-</div><div>specific announcers) with the 2017 Frick Award; <span>National Voices<span> (broadcasters whose contributions were</span></span></div><div>realized on a national level) with the 2018 Frick Award; and <span>Broadcasting Beginnings</span> (early team voices and</div><div>pioneers of baseball broadcasting) with the 2019 Frick Award. This cycle will repeat every three years.</div><div>[3]</div><div>The Hall announced the following finalists for the 2018 Ford C. Frick Award on October 23, 2017.</div><div>[18]</div></div>
# <div><div>Buddy Blattner</div><div>Joe Buck</div><div>Bob Costas</div><div>Dizzy Dean</div><div>Don Drysdale</div><div>Al Michaels</div><div>Joe Morgan</div><div>Pee Wee Reese</div><div>Four finalists were members of the Hall of Fame as players—Dean, Drysdale, Morgan and Reese. When the</div><div>ballot was announced, Buck, Costas, Michaels and Morgan were still alive. The other four were</div><div>deceased.</div><div>[18]</div><div>Costas was announced as the recipient at the 2017 winter meetings on December 13. He began his</div><div>sportscasting career as a play-by-play caller for the <span>Spirits of St. Louis</span> in the <span>American Basketball</span></div><div>Association<span>, and went from there to calling </span>NBA<span> and <span>NFL</span> games for <span>CBS</span>, but made his greatest mark as</span></div><div>part of <span>NBC</span>'s broadcast team for its national MLB telecasts from 1982 to 2009. Costas then joined the <span>MLB</span></div><div>Network<span>, where he was serving as the network's documentary host when he was announced as the Frick</span></div><div>Award recipient.</div><div>[19]</div><div>References <span>[<span>edit</span>]</span></div><div>1. ^ </div><div>a</div><div>b</div><div> <span>"Baseball Hall of Fame adds four new members"</span>. <span>ESPN.com</span>. January 24, 2018. Retrieved January 24,</div><div>2018.</div><div>2. <span>^</span> <span>"Hall of Fame Board of Directors Restructures Procedures for Consideration of Managers, Umpires, Executives</span></div><div>and Long-Retired Players"<span> (Press release). National Baseball Hall of Fame and Museum. July 26, 2010.</span></div><div>Retrieved January 15, 2011.</div><div>3. ^ </div><div>a</div><div>b</div><div>c</div><div>d</div> <span>"Hall of Fame Makes Series of Announcements"<span> (Press release). National Baseball Hall of Fame and</span></span><div>Museum. July 23, 2016. Retrieved August 14, 2016.</div><div>4. ^ </div><div>a</div><div>b</div> <span>"Jack Morris, Alan Trammell Elected to Hall of Fame by Modern Baseball Era Committee"<span> (Press release).</span></span><div>National Baseball Hall of Fame and Museum. December 10, 2017. Retrieved December 10, 2017.</div><div>5. <span>^</span> Bloom, Barry J. (December 6, 2016). <span>"Hall of Fame ballots will be made public starting in 2018"<span>. mlb.com.</span></span></div><div>Retrieved January 18, 2017.</div><div>6. <span>^</span> Calcaterra, Craig (November 20, 2017). <span>"The Hall of Fame rejected the BBWAA vote to make ballots public"<span>.</span></span></div><div>NBC Sports. Retrieved December 11, 2017.</div><div>7. <span>^</span> <span>"Hall of Fame Announces Change to BBWAA Voting Electorate"<span> (Press release). National Baseball Hall of</span></span></div><div>Fame and Museum. July 28, 2015. Retrieved July 28, 2015.</div><div>8. <span>^</span> <span>"Ken Griffey Jr. (99 percent of vote), Mike Piazza head to Cooperstown"<span>. espn.go.com. January 6, 2016.</span></span></div><div>Retrieved January 6, 2016.</div><div>9. <span>^</span> Baseball Hall of Fame. <span>"BBWAA elects 4 to Hall of Fame"<span>.</span></span></div><div>10. <span>^</span> Axisa, Mike (January 24, 2022). <span>"2023 Baseball Hall of Fame voting results: Scott Rolen squeaks in, will join</span></div><div>Fred McGriff in Cooperstown"<span>. <span>CBSSports.com</span>. Retrieved January 24, 2022.</span></div></div>
# <div><div>Privacy policyAbout WikipediaDisclaimersContact WikipediaCode of ConductDevelopersStatisticsCookie statement</div><div>Mobile view</div><div>This page was last edited on 3 April 2025, at 20:07(UTC).</div><div>Text is available under the <span>Creative Commons Attribution-ShareAlike 4.0 License<span>; additional terms may apply. By using this site, you agree to the</span></span></div><div>Terms of Use<span> and </span>Privacy Policy<span>. Wikipedia® is a registered trademark of the <span>Wikimedia Foundation, Inc.</span>, a non-profit organization.</span></div><div>Baseball portal</div><div>[<span>show</span>]<span>V<span> · <span>T<span> · <span>E</span></span></span></span></span></div><div>[<span>show</span>]<span>V<span> · <span>T<span> · <span>E</span></span></span></span></span></div><div>11. <span>^</span> <span>"2018 Modern Baseball Era Ballot"</span> (Press release). National Baseball Hall of Fame and Museum. November</div><div>6, 2017. Retrieved December 2, 2017.</div><div>12. ^ </div><div>a</div><div>b</div><div>c</div><div>d</div><div>e</div><div>f</div><div>g</div><div>h</div><div>i</div><div>j</div><div> Axisa, Mike (December 10, 2017). <span>"Jack Morris and Alan Trammell voted into Hall of Fame by</span></div><div>Modern Era Committee"<span>. <span>CBS Sports</span>. Retrieved December 13, 2017.</span></div><div>13. <span>^</span> <span>"J.G. Taylor Spink Award"<span>. baseball-almanac.com. Retrieved July 20, 2010.</span></span></div><div>14. <span>^</span> <span>"Awards: J. G. Taylor Spink"<span>. National Baseball Hall of Fame and Museum. Retrieved January 11, 2014.</span></span></div><div>15. <span>^</span> Miller, Phil (July 11, 2017). <span>"Patrick Reusse nominated for Baseball Hall of Fame honor"</span>. <span>Star Tribune<span>.</span></span></div><div>Minneapolis<span>. Retrieved December 2, 2017.</span></div><div>16. <span>^</span> Francis, William (December 12, 2017). <span>"2018 J. G. Taylor Spink Award Winner Sheldon Ocker"<span>.</span></span></div><div>baseballhall.org<span>. Retrieved December 18, 2017.</span></div><div>17. <span>^</span> Castrovince, Anthony (December 12, 2017). <span>"Ocker honored as 2018 Spink Award recipient"<span>. </span><span>MLB.com<span>.</span></span></span></div><div>Retrieved December 13, 2017.</div><div>18. ^ </div><div>a</div><div>b</div> <span>"2018 Ford C. Frick Award Ballot"<span> (Press release). National Baseball Hall of Fame and Museum. October</span></span><div>23, 2017. Retrieved November 7, 2017.</div><div>19. <span>^</span> Macklin, Oliver (December 13, 2017). <span>"'National treasure' Costas wins '18 Frick Award"<span>. </span><span>MLB.com<span>. Retrieved</span></span></span></div><div>December 13, 2017.</div><div>External links <span>[<span>edit</span>]</span></div><div>National Baseball Hall of Fame official website</div><div>BBWAA rules for election to the Hall of Fame</div><div>Balloting for the <span>National Baseball Hall of Fame</span></div><div>Baseball Hall of Fame<span> Class of 2018</span></div><div>Categories<span>: </span>Baseball Hall of Fame balloting2018 in baseball</div></div>
# </div>

# %%
# Maximum number of words in a node when constructing the block tree for pruning with the embedding model
# MAX_NODE_WORDS_EMBED = 10 
MAX_NODE_WORDS_EMBED = 256 # a recommended setting for real-world HTML documents
# Maximum number of tokens in the output HTML document pruned with the embedding model
# MAX_CONTEXT_WINDOW_EMBED = 60
MAX_CONTEXT_WINDOW_EMBED = 6144 # a recommended setting for real-world HTML documents
# Maximum number of words in a node when constructing the block tree for pruning with the generative model
# MAX_NODE_WORDS_GEN = 5
MAX_NODE_WORDS_GEN = 128 # a recommended setting for real-world HTML documents
# Maximum number of tokens in the output HTML document pruned with the generative model
# MAX_CONTEXT_WINDOW_GEN = 32
MAX_CONTEXT_WINDOW_GEN = 4096 # a recommended setting for real-world HTML documents

# %% [markdown]
# # Build tree

# %%
block_1, html_1 = build_block_tree(simplified_html, max_node_words=MAX_NODE_WORDS_EMBED)
# block_tree, simplified_html = build_block_tree(simplified_html, max_node_words=MAX_NODE_WORDS_GEN, zh_char=True) # for Chinese text
for block in block_1:
    print("Block Content: ", block[0])
    print("Block Path: ", block[1])
    print("Is Leaf: ", block[2])
    print("")

# Block Content:  <h1>Bellagio Hotel in Las</h1>
# Block Path:  ['html', 'title']
# Is Leaf:  True
# 
# Block Content:  <div>
# <p>Some other text</p>
# <p>Some other text</p>
# </div>
# Block Path:  ['html', 'div']
# Is Leaf:  True
# 
# Block Content:  <p>The Bellagio is a luxury hotel and casino located on the Las Vegas Strip in Paradise, Nevada. It was built in 1998.</p>
# Block Path:  ['html', 'p']
# Is Leaf:  True
# Out:
# Block Content:  <div1><div>ballots.</div><div></div><div>Eliminated from annual BBWAA consideration by</div><div>poor performance or expiration on this ballot.</div><div>†First time on the BBWAA ballot.</div><div>*</div><div>Eliminated from annual BBWAA consideration by</div><div>poor performance on this ballot (not expiration).</div><div>Chipper Jones</div><div>Another recent rules change, announced in 2015,</div><div>tightened the qualifications for the BBWAA</div><div>electorate. Beginning with the 2016 election,</div><div>eligible voters must not only have 10years of</div><div>continuous BBWAA membership, but also be</div><div>currently active members, or have held active</div><div>status within the 10years prior to the election. A</div><div>BBWAA member who has not been active for more</div><div>than 10years can regain voting status by covering MLB in the year preceding the election.</div><div>[7]</div><div> As a result of</div><div>the new rule, the vote total in 2016 decreased by 109 from the previous year, to 440.</div><div>[8]</div><div>The ballot included two categories of players:</div><div>Candidates from the 2017 ballot who received at least 5% of the vote but were not elected, as long as</div><div>they first appeared on the BBWAA ballot no earlier than 2009.</div><div>Selected individuals, chosen by a screening committee, whose last MLB appearance was in 2012.</div><div>422 ballots were cast, 20 fewer than in 2017. There were 422 ballots cast, with a total of 3570 votes for</div><div>individual players, an average of 8.46 names per ballot—the highest per-ballot average since 1960 (8.51</div><div>votes per ballot).</div><div>Voting results from 2018:</div><div>[9]</div><div>PlayerVotesPercentChangeYear</div><div>Chipper Jones<span>†<span>41097.2%–1st</span></span></div><div>Vladimir Guerrero<span>39292.9%21.2%2nd</span></div><div>Jim Thome<span>†<span>37989.8%–1st</span></span></div><div>Trevor Hoffman<span>33779.9%5.9%3rd</span></div><div>Edgar Martínez<span>29770.4%11.8%9th</span></div><div>Mike Mussina<span>26863.5%11.7%5th</span></div><div>Roger Clemens<span>24257.3%3.2%6th</span></div><div>Barry Bonds<span>23856.4%2.6%6th</span></div><div>Curt Schilling<span>21651.2%6.2%6th</span></div><div>Omar Vizquel<span>†<span>15637.0%–1st</span></span></div><div>Larry Walker<span>14434.1%12.2%8th</span></div><div>Fred McGriff<span>9823.2%1.5%9th</span></div><div>Manny Ramírez<span>9322.0%1.8%2nd</span></div><div>Jeff Kent<span>6114.5%2.2%5th</span></div><div>Gary Sheffield<span>4711.1%2.2%4th</span></div></div1>
# Block Path:  ['div', 'div1']
# Is Leaf:  True
#
# Block Content:  <div2><div>Vladimir Guerrero</div><div>Jim Thome</div><div>Trevor Hoffman</div><div>Billy Wagner<span>4711.1%0.9%3rd</span></div><div>Scott Rolen<span>†<span>4310.2%–1st</span></span></div><div>Sammy Sosa<span>337.8%0.8%6th</span></div><div>Andruw Jones<span>†<span>317.3%–1st</span></span></div><div>Jamie Moyer<span>†*<span>102.4%–1st</span></span></div><div>Johan Santana<span>†*<span>102.4%–1st</span></span></div><div>Johnny Damon<span>†*<span>81.9%–1st</span></span></div><div>Hideki Matsui<span>†*<span>40.9%–1st</span></span></div><div>Chris Carpenter<span>†*<span>20.5%–1st</span></span></div><div>Kerry Wood<span>†*<span>20.5%–1st</span></span></div><div>Liván Hernández<span>†*<span>10.2%–1st</span></span></div><div>Carlos Lee<span>†*<span>10.2%–1st</span></span></div><div>Orlando Hudson<span>†*<span>00%–1st</span></span></div><div>Aubrey Huff<span>†*<span>00%–1st</span></span></div><div>Jason Isringhausen<span>†*<span>00%–1st</span></span></div><div>Brad Lidge<span>†*<span>00%–1st</span></span></div><div>Kevin Millwood<span>†*<span>00%–1st</span></span></div><div>Carlos Zambrano<span>†*<span>00%–1st</span></span></div><div>Players who were eligible for the first time in 2018 but were <span>not</span> on</div><div>the ballot included <span>Rod Barajas</span>, <span>Miguel Batista</span>, <span>Geoff Blum</span>, <span>Miguel</span></div><div>Cairo<span>, <span>Aaron Cook<span>, </span>Francisco Cordero<span>, </span>Juan Cruz<span>, </span>Brian Fuentes<span>,</span></span></span></div><div>Bill Hall<span>, </span>Willie Harris<span>, </span>Nick Johnson<span>, <span>Adam Kennedy<span>, <span>Rodrigo</span></span></span></span></div><div>López<span>, </span>Mike MacDougal<span>, </span>Guillermo Mota<span>, </span>Will Ohman<span>, </span>Vicente</div><div>Padilla<span>, </span>Carl Pavano<span>, </span>Scott Podsednik<span>, </span>Juan Rivera<span>, </span>J. C. Romero<span>,</span></div><div>Brian Schneider<span>, <span>Ben Sheets</span>, <span>Jeff Suppan</span>, <span>Kip Wells</span>, <span>Dan Wheeler</span></span></div><div>and <span>Jack Wilson</span>.</div><div>Scott Rolen's 10.2% was the lowest first-year vote percentage in</div><div>history for a candidate who was eventually elected by the BBWAA.</div><div>He was voted in on the <span>2023 ballot</span>.</div><div>[10]</div><div>Modern Baseball Era Committee <span>[<span>edit</span>]</span></div><div>On July 23, 2016, the Hall of Fame announced changes to the Era Committee system. The system's</div><div>timeframes were restructured to place a greater emphasis on the modern game, and to reduce the</div></div2>
# Block Path:  ['div', 'div2']
# Is Leaf:  True
#
# Block Content:  <div3><div>Jack Morris</div><div>Alan Trammell</div><div>frequency at which individuals from the pre-1970 game (including</div><div>Negro league baseball<span> figures) will have their careers reviewed.</span></div><div>[3]</div><div>Considering candidates whose greatest contributions occurred from</div><div>1970 to 1987, the Modern Baseball Era Committee met in 2017 as</div><div>part of the elections for the next calendar year.</div><div>Further information: <span>Veterans Committee §2016 revisions</span></div><div>On November 6, 2017, the Hall announced the 10 candidates to be</div><div>considered when the Modern Baseball Era Committee met at the</div><div>2017 winter meetings near <span>Walt Disney World<span> on December 10, with</span></span></div><div>the voting results announced immediately after the committee</div><div>met.</div><div>[11]</div><div> The cutoff for election and induction remained the standard</div><div>75%, or 12 of 16 votes.</div><div>The committee consisted of the following individuals:</div><div>[4]</div><div>Hall of Famers: <span>George Brett</span>, <span>Rod Carew<span>, <span>Bobby Cox</span>, <span>Dennis</span></span></span></div><div>Eckersley<span>, <span>John Schuerholz</span>, <span>Don Sutton</span>, <span>Dave Winfield</span>, <span>Robin</span></span></div><div>Yount</div><div>Executives: <span>Sandy Alderson<span>, </span>Paul Beeston<span>, </span>Bob Castellini<span>, </span>David</span></div><div>Glass<span>, </span>Bill DeWitt</div><div>Media and historians: <span>Bob Elliott</span>, <span>Steve Hirdt</span>, <span>Jayson Stark</span></div><div>Non-voting committee chair: Jane Forbes Clark (Hall of Fame</div><div>chairman)</div><div>CandidateCategoryVotesPercentRef</div><div>Jack Morris<span>Player1487.5%</span></div><div>[12]</div><div>Alan Trammell<span>Player1381.3%</span></div><div>[12]</div><div>Ted Simmons<span>Player1168.8%</span></div><div>[12]</div><div>Marvin Miller<span>Executive743.8%</span></div><div>[12]</div><div>Steve Garvey<span>Player&lt;7–</span></div><div>[12]</div><div>Tommy John<span>Player&lt;7–</span></div><div>[12]</div><div>Don Mattingly<span>Player&lt;7–</span></div><div>[12]</div><div>Dale Murphy<span>Player&lt;7–</span></div><div>[12]</div><div>Dave Parker<span>Player&lt;7–</span></div><div>[12]</div><div>Luis Tiant<span>Player&lt;7–</span></div><div>[12]</div><div>All candidates except Miller were living when the ballot and voting results were announced. Mattingly,</div><div>Morris, Murphy and Trammell were being considered for the first time; the others had been considered at</div></div3>
# Block Path:  ['div', 'div3']
# Is Leaf:  True
#
# Block Content:  <div0>2018 Baseball Hall of Fame balloting</div0>
# Block Path:  ['div', 'div0', 'div0']
# Is Leaf:  True
#
# Block Content:  <div1>1 language</div1>
# Block Path:  ['div', 'div0', 'div1']
# Is Leaf:  True
#
# Block Content:  <div2>Article<span>Talk<span>Read</span>EditView history</span></div2>
# Block Path:  ['div', 'div0', 'div2']
# Is Leaf:  True
#
# Block Content:  <div3>Tools</div3>
# Block Path:  ['div', 'div0', 'div3']
# Is Leaf:  True
#
# Block Content:  <div4><div>←<span>20172019</span>→</div><div>2018 Baseball Hall of Fame</div><div>balloting</div><div>   National Baseball   </div><div>Hall of Fame and Museum</div><div>New inductees<span>6</span></div><div>via BBWAA<span>4</span></div><div>via Modern Baseball Era</div><div>Committee</div><div>2</div><div>Total inductees<span>323</span></div><div>Induction date<span>July 29, 2018</span></div><div>Key</div><div></div><div>Elected to the Hall of Fame on this ballot (named</div><div>in <span>bold italics</span>).</div><div></div><div>Elected subsequently, as of 2025 (named in <span>plain</span></div><div>italics<span>).</span></div><div></div><div>Renominated for the <span>2019 BBWAA election<span> by</span></span></div><div>adequate performance on this ballot and has not</div><div>subsequently been eliminated.</div><div>Eliminated from annual BBWAA consideration by</div><div>poor performance or expiration on subsequent</div></div4>
# Block Path:  ['div', 'div0', 'div4']
# Is Leaf:  True
#
# Block Content:  <div5>From Wikipedia, the free encyclopedia</div5>
# Block Path:  ['div', 'div0', 'div5']
# Is Leaf:  True
#
# Block Content:  <div6><div>(Redirected from <span>Baseball Hall of Fame balloting, 2018</span>)</div><div>Elections to the <span>National Baseball Hall of Fame</span> for 2018</div><div>proceeded according to rules most recently amended in 2016.</div><div>As in the past, the <span>Baseball Writers' Association of America</span></div><div>(BBWAA) voted by mail to select from a ballot of recently</div><div>retired players. The results were announced on January 24,</div><div>2018, with the BBWAA electing <span>Chipper Jones</span>, <span>Vladimir</span></div><div>Guerrero<span>, </span>Jim Thome<span> and <span>Trevor Hoffman<span> to the Hall of Fame.</span></span></span></div><div>Jones and Thome were elected in their first year of eligibility.</div><div>[1]</div><div>The three voting panels that replaced the more broadly</div><div>defined <span>Veterans Committee<span> following a 2010 rules change</span></span></div><div>[2]</div><div>were replaced by a new set of four panels in 2016.</div><div>[3]</div><div> The</div><div>Modern Baseball Era Committee<span> convened on December 10,</span></div><div>2017, to select from a ballot of retired players and non-playing personnel who made their greatest</div><div>contributions to the sport between 1970 and 1987,</div><div>[3]</div><div> with <span>Jack Morris</span> and <span>Alan Trammell<span> elected by this</span></span></div><div>body.</div><div>[4]</div><div> The formal induction ceremony was held at the Hall's facilities in <span>Cooperstown, New York<span>, on July</span></span></div><div>29, 2018.</div><div>[1]</div><div>BBWAA election <span>[<span>edit</span>]</span></div><div>The BBWAA election rules remained identical to</div><div>those that were in effect for the most recent</div><div>elections. The BBWAA voted at the 2016 winter</div><div>meetings to make all Hall of Fame ballots public</div><div>one week after the results were announced,</div><div>effective with this election.</div><div>[5]</div><div> However, the Hall</div><div>rejected the BBWAA's proposal, and ballots remain</div><div>confidential unless individual voters choose to</div><div>reveal them (which is allowed by Hall of Fame</div><div>rules).</div><div>[6]</div><div>DonateCreate accountLog in</div></div6>
# Block Path:  ['div', 'div0', 'div6']
# Is Leaf:  True
#
# Block Content:  <div0>least once by one of the predecessors to this committee. Garvey, John, Miller, Parker and Simmons were</div0>
# Block Path:  ['div', 'div4', 'div0']
# Is Leaf:  True
#
# Block Content:  <div1>most recently considered in 2014 by the former Expansion Era Committee, and Tiant was most recently</div1>
# Block Path:  ['div', 'div4', 'div1']
# Is Leaf:  True
#
# Block Content:  <div2>considered by the former Golden Era Committee in 2015. Among players, Simmons was the only candidate</div2>
# Block Path:  ['div', 'div4', 'div2']
# Is Leaf:  True
#
# Block Content:  <div3>who was not on the BBWAA ballot for the full 15-year period formerly allowed by Hall rules; he received less</div3>
# Block Path:  ['div', 'div4', 'div3']
# Is Leaf:  True
#
# Block Content:  <div4>than 5% when he debuted on the BBWAA ballot in 1994 and thus did not appear on further ballots. The Hall</div4>
# Block Path:  ['div', 'div4', 'div4']
# Is Leaf:  True
#
# Block Content:  <div5>changed the eligibility period to 10 years starting with the 2015 election, but Trammell and Mattingly (who</div5>
# Block Path:  ['div', 'div4', 'div5']
# Is Leaf:  True
#
# Block Content:  <div6>were then past the new 10-year cutoff) retained their original 15-year eligibility window.</div6>
# Block Path:  ['div', 'div4', 'div6']
# Is Leaf:  True
#
# Block Content:  <div7>J. G. Taylor Spink Award <span>[<span>edit</span>]</span></div7>
# Block Path:  ['div', 'div4', 'div7']
# Is Leaf:  True
#
# Block Content:  <div8>The <span>J. G. Taylor Spink Award<span> has been presented by the BBWAA at the annual summer induction</span></span></div8>
# Block Path:  ['div', 'div4', 'div8']
# Is Leaf:  True
#
# Block Content:  <div9>ceremonies since 1962.</div9>
# Block Path:  ['div', 'div4', 'div9']
# Is Leaf:  True
#
# Block Content:  <div10>[13]</div10>
# Block Path:  ['div', 'div4', 'div10']
# Is Leaf:  True
#
# Block Content:  <div11> Through 2010, it was awarded during the main induction ceremony, but is now</div11>
# Block Path:  ['div', 'div4', 'div11']
# Is Leaf:  True
#
# Block Content:  <div12>given the previous day at the Hall of Fame Awards Presentation. It recognizes a <span>sportswriter</span> "for meritorious</div12>
# Block Path:  ['div', 'div4', 'div12']
# Is Leaf:  True
#
# Block Content:  <div13>contributions to baseball writing".</div13>
# Block Path:  ['div', 'div4', 'div13']
# Is Leaf:  True
#
# Block Content:  <div14>[14]</div14>
# Block Path:  ['div', 'div4', 'div14']
# Is Leaf:  True
#
# Block Content:  <div15> The recipients are not members of the Hall of Fame but are featured in</div15>
# Block Path:  ['div', 'div4', 'div15']
# Is Leaf:  True
#
# Block Content:  <div16>a permanent exhibit at the National Baseball Museum.</div16>
# Block Path:  ['div', 'div4', 'div16']
# Is Leaf:  True
#
# Block Content:  <div17>The three finalists for the 2018 award were announced during the 2017 <span>All-Star<span> break.</span></span></div17>
# Block Path:  ['div', 'div4', 'div17']
# Is Leaf:  True
#
# Block Content:  <div18>[15]</div18>
# Block Path:  ['div', 'div4', 'div18']
# Is Leaf:  True
#
# Block Content:  <div19>Sheldon Ocker<span>, </span><span>Akron Beacon-Journal<span> (retired)</span></span></div19>
# Block Path:  ['div', 'div4', 'div19']
# Is Leaf:  True
#
# Block Content:  <div20>Jim Reeves, <span>Fort Worth Star-Telegram</span></div20>
# Block Path:  ['div', 'div4', 'div20']
# Is Leaf:  True
#
# Block Content:  <div21>Patrick Reusse<span>, </span><span>Star Tribune<span> (Minneapolis)</span></span></div21>
# Block Path:  ['div', 'div4', 'div21']
# Is Leaf:  True
#
# Block Content:  <div22>Ocker was announced as the recipient during the 2017 winter meetings on December 12.</div22>
# Block Path:  ['div', 'div4', 'div22']
# Is Leaf:  True
#
# Block Content:  <div23>[16]</div23>
# Block Path:  ['div', 'div4', 'div23']
# Is Leaf:  True
#
# Block Content:  <div24> He covered the</div24>
# Block Path:  ['div', 'div4', 'div24']
# Is Leaf:  True
#
# Block Content:  <div25>Cleveland Indians for more than three decades, serving as Cleveland Indians beat reporter for the <span>Beacon-</span></div25>
# Block Path:  ['div', 'div4', 'div25']
# Is Leaf:  True
#
# Block Content:  <div26>Journal<span> from 1981 until his retirement at the end of the 2013 season. Ocker received 168 of the 426 ballots</span></div26>
# Block Path:  ['div', 'div4', 'div26']
# Is Leaf:  True
#
# Block Content:  <div27>cast (including two blanks) to Reeves' 143 and Reusse's 113.</div27>
# Block Path:  ['div', 'div4', 'div27']
# Is Leaf:  True
#
# Block Content:  <div28>[17]</div28>
# Block Path:  ['div', 'div4', 'div28']
# Is Leaf:  True
#
# Block Content:  <div29>Ford C. Frick Award <span>[<span>edit</span>]</span></div29>
# Block Path:  ['div', 'div4', 'div29']
# Is Leaf:  True
#
# Block Content:  <div30>Various changes in July 2016 were also made to the annual <span>Ford C. Frick Award<span> elections, presented</span></span></div30>
# Block Path:  ['div', 'div4', 'div30']
# Is Leaf:  True
#
# Block Content:  <div31>annually to a preeminent baseball broadcaster since 1978. According to the Hall, the new criteria for</div31>
# Block Path:  ['div', 'div4', 'div31']
# Is Leaf:  True
#
# Block Content:  <div32>selection are "Commitment to excellence, quality of broadcasting abilities, reverence within the game,</div32>
# Block Path:  ['div', 'div4', 'div32']
# Is Leaf:  True
#
# Block Content:  <div33>popularity with fans, and recognition by peers."</div33>
# Block Path:  ['div', 'div4', 'div33']
# Is Leaf:  True
#
# Block Content:  <div34>Additionally, a ballot of eight candidates will now be set, down from 10 in years past. The three ballot slots</div34>
# Block Path:  ['div', 'div4', 'div34']
# Is Leaf:  True
#
# Block Content:  <div35>previously determined by fan voting on <span>Facebook</span> will now be filled by a committee of historians.</div35>
# Block Path:  ['div', 'div4', 'div35']
# Is Leaf:  True
#
# Block Content:  <div36>A new election cycle has been established, rotating annually between <span>Current Major League Markets</span> (team-</div36>
# Block Path:  ['div', 'div4', 'div36']
# Is Leaf:  True
#
# Block Content:  <div37>specific announcers) with the 2017 Frick Award; <span>National Voices<span> (broadcasters whose contributions were</span></span></div37>
# Block Path:  ['div', 'div4', 'div37']
# Is Leaf:  True
#
# Block Content:  <div38>realized on a national level) with the 2018 Frick Award; and <span>Broadcasting Beginnings</span> (early team voices and</div38>
# Block Path:  ['div', 'div4', 'div38']
# Is Leaf:  True
#
# Block Content:  <div39>pioneers of baseball broadcasting) with the 2019 Frick Award. This cycle will repeat every three years.</div39>
# Block Path:  ['div', 'div4', 'div39']
# Is Leaf:  True
#
# Block Content:  <div40>[3]</div40>
# Block Path:  ['div', 'div4', 'div40']
# Is Leaf:  True
#
# Block Content:  <div41>The Hall announced the following finalists for the 2018 Ford C. Frick Award on October 23, 2017.</div41>
# Block Path:  ['div', 'div4', 'div41']
# Is Leaf:  True
#
# Block Content:  <div42>[18]</div42>
# Block Path:  ['div', 'div4', 'div42']
# Is Leaf:  True
#
# Block Content:  <div0>Buddy Blattner</div0>
# Block Path:  ['div', 'div5', 'div0']
# Is Leaf:  True
#
# Block Content:  <div1>Joe Buck</div1>
# Block Path:  ['div', 'div5', 'div1']
# Is Leaf:  True
#
# Block Content:  <div2>Bob Costas</div2>
# Block Path:  ['div', 'div5', 'div2']
# Is Leaf:  True
#
# Block Content:  <div3>Dizzy Dean</div3>
# Block Path:  ['div', 'div5', 'div3']
# Is Leaf:  True
#
# Block Content:  <div4>Don Drysdale</div4>
# Block Path:  ['div', 'div5', 'div4']
# Is Leaf:  True
#
# Block Content:  <div5>Al Michaels</div5>
# Block Path:  ['div', 'div5', 'div5']
# Is Leaf:  True
#
# Block Content:  <div6>Joe Morgan</div6>
# Block Path:  ['div', 'div5', 'div6']
# Is Leaf:  True
#
# Block Content:  <div7>Pee Wee Reese</div7>
# Block Path:  ['div', 'div5', 'div7']
# Is Leaf:  True
#
# Block Content:  <div8>Four finalists were members of the Hall of Fame as players—Dean, Drysdale, Morgan and Reese. When the</div8>
# Block Path:  ['div', 'div5', 'div8']
# Is Leaf:  True
#
# Block Content:  <div9>ballot was announced, Buck, Costas, Michaels and Morgan were still alive. The other four were</div9>
# Block Path:  ['div', 'div5', 'div9']
# Is Leaf:  True
#
# Block Content:  <div10>deceased.</div10>
# Block Path:  ['div', 'div5', 'div10']
# Is Leaf:  True
#
# Block Content:  <div11>[18]</div11>
# Block Path:  ['div', 'div5', 'div11']
# Is Leaf:  True
#
# Block Content:  <div12>Costas was announced as the recipient at the 2017 winter meetings on December 13. He began his</div12>
# Block Path:  ['div', 'div5', 'div12']
# Is Leaf:  True
#
# Block Content:  <div13>sportscasting career as a play-by-play caller for the <span>Spirits of St. Louis</span> in the <span>American Basketball</span></div13>
# Block Path:  ['div', 'div5', 'div13']
# Is Leaf:  True
#
# Block Content:  <div14>Association<span>, and went from there to calling </span>NBA<span> and <span>NFL</span> games for <span>CBS</span>, but made his greatest mark as</span></div14>
# Block Path:  ['div', 'div5', 'div14']
# Is Leaf:  True
#
# Block Content:  <div15>part of <span>NBC</span>'s broadcast team for its national MLB telecasts from 1982 to 2009. Costas then joined the <span>MLB</span></div15>
# Block Path:  ['div', 'div5', 'div15']
# Is Leaf:  True
#
# Block Content:  <div16>Network<span>, where he was serving as the network's documentary host when he was announced as the Frick</span></div16>
# Block Path:  ['div', 'div5', 'div16']
# Is Leaf:  True
#
# Block Content:  <div17>Award recipient.</div17>
# Block Path:  ['div', 'div5', 'div17']
# Is Leaf:  True
#
# Block Content:  <div18>[19]</div18>
# Block Path:  ['div', 'div5', 'div18']
# Is Leaf:  True
#
# Block Content:  <div19>References <span>[<span>edit</span>]</span></div19>
# Block Path:  ['div', 'div5', 'div19']
# Is Leaf:  True
#
# Block Content:  <div20>1. ^ </div20>
# Block Path:  ['div', 'div5', 'div20']
# Is Leaf:  True
#
# Block Content:  <div21>a</div21>
# Block Path:  ['div', 'div5', 'div21']
# Is Leaf:  True
#
# Block Content:  <div22>b</div22>
# Block Path:  ['div', 'div5', 'div22']
# Is Leaf:  True
#
# Block Content:  <div23> <span>"Baseball Hall of Fame adds four new members"</span>. <span>ESPN.com</span>. January 24, 2018. Retrieved January 24,</div23>
# Block Path:  ['div', 'div5', 'div23']
# Is Leaf:  True
#
# Block Content:  <div24>2018.</div24>
# Block Path:  ['div', 'div5', 'div24']
# Is Leaf:  True
#
# Block Content:  <div25>2. <span>^</span> <span>"Hall of Fame Board of Directors Restructures Procedures for Consideration of Managers, Umpires, Executives</span></div25>
# Block Path:  ['div', 'div5', 'div25']
# Is Leaf:  True
#
# Block Content:  <div26>and Long-Retired Players"<span> (Press release). National Baseball Hall of Fame and Museum. July 26, 2010.</span></div26>
# Block Path:  ['div', 'div5', 'div26']
# Is Leaf:  True
#
# Block Content:  <div27>Retrieved January 15, 2011.</div27>
# Block Path:  ['div', 'div5', 'div27']
# Is Leaf:  True
#
# Block Content:  <div28>3. ^ </div28>
# Block Path:  ['div', 'div5', 'div28']
# Is Leaf:  True
#
# Block Content:  <div29>a</div29>
# Block Path:  ['div', 'div5', 'div29']
# Is Leaf:  True
#
# Block Content:  <div30>b</div30>
# Block Path:  ['div', 'div5', 'div30']
# Is Leaf:  True
#
# Block Content:  <div31>c</div31>
# Block Path:  ['div', 'div5', 'div31']
# Is Leaf:  True
#
# Block Content:  <div32>d</div32>
# Block Path:  ['div', 'div5', 'div32']
# Is Leaf:  True
#
# Block Content:  <span0>"Hall of Fame Makes Series of Announcements"<span> (Press release). National Baseball Hall of Fame and</span></span0>
# Block Path:  ['div', 'div5', 'span0']
# Is Leaf:  True
#
# Block Content:  <div33>Museum. July 23, 2016. Retrieved August 14, 2016.</div33>
# Block Path:  ['div', 'div5', 'div33']
# Is Leaf:  True
#
# Block Content:  <div34>4. ^ </div34>
# Block Path:  ['div', 'div5', 'div34']
# Is Leaf:  True
#
# Block Content:  <div35>a</div35>
# Block Path:  ['div', 'div5', 'div35']
# Is Leaf:  True
#
# Block Content:  <div36>b</div36>
# Block Path:  ['div', 'div5', 'div36']
# Is Leaf:  True
#
# Block Content:  <span1>"Jack Morris, Alan Trammell Elected to Hall of Fame by Modern Baseball Era Committee"<span> (Press release).</span></span1>
# Block Path:  ['div', 'div5', 'span1']
# Is Leaf:  True
#
# Block Content:  <div37>National Baseball Hall of Fame and Museum. December 10, 2017. Retrieved December 10, 2017.</div37>
# Block Path:  ['div', 'div5', 'div37']
# Is Leaf:  True
#
# Block Content:  <div38>5. <span>^</span> Bloom, Barry J. (December 6, 2016). <span>"Hall of Fame ballots will be made public starting in 2018"<span>. mlb.com.</span></span></div38>
# Block Path:  ['div', 'div5', 'div38']
# Is Leaf:  True
#
# Block Content:  <div39>Retrieved January 18, 2017.</div39>
# Block Path:  ['div', 'div5', 'div39']
# Is Leaf:  True
#
# Block Content:  <div40>6. <span>^</span> Calcaterra, Craig (November 20, 2017). <span>"The Hall of Fame rejected the BBWAA vote to make ballots public"<span>.</span></span></div40>
# Block Path:  ['div', 'div5', 'div40']
# Is Leaf:  True
#
# Block Content:  <div41>NBC Sports. Retrieved December 11, 2017.</div41>
# Block Path:  ['div', 'div5', 'div41']
# Is Leaf:  True
#
# Block Content:  <div42>7. <span>^</span> <span>"Hall of Fame Announces Change to BBWAA Voting Electorate"<span> (Press release). National Baseball Hall of</span></span></div42>
# Block Path:  ['div', 'div5', 'div42']
# Is Leaf:  True
#
# Block Content:  <div43>Fame and Museum. July 28, 2015. Retrieved July 28, 2015.</div43>
# Block Path:  ['div', 'div5', 'div43']
# Is Leaf:  True
#
# Block Content:  <div44>8. <span>^</span> <span>"Ken Griffey Jr. (99 percent of vote), Mike Piazza head to Cooperstown"<span>. espn.go.com. January 6, 2016.</span></span></div44>
# Block Path:  ['div', 'div5', 'div44']
# Is Leaf:  True
#
# Block Content:  <div45>Retrieved January 6, 2016.</div45>
# Block Path:  ['div', 'div5', 'div45']
# Is Leaf:  True
#
# Block Content:  <div46>9. <span>^</span> Baseball Hall of Fame. <span>"BBWAA elects 4 to Hall of Fame"<span>.</span></span></div46>
# Block Path:  ['div', 'div5', 'div46']
# Is Leaf:  True
#
# Block Content:  <div47>10. <span>^</span> Axisa, Mike (January 24, 2022). <span>"2023 Baseball Hall of Fame voting results: Scott Rolen squeaks in, will join</span></div47>
# Block Path:  ['div', 'div5', 'div47']
# Is Leaf:  True
#
# Block Content:  <div48>Fred McGriff in Cooperstown"<span>. <span>CBSSports.com</span>. Retrieved January 24, 2022.</span></div48>
# Block Path:  ['div', 'div5', 'div48']
# Is Leaf:  True
#
# Block Content:  <div0>Privacy policyAbout WikipediaDisclaimersContact WikipediaCode of ConductDevelopersStatisticsCookie statement</div0>
# Block Path:  ['div', 'div6', 'div0']
# Is Leaf:  True
#
# Block Content:  <div1>Mobile view</div1>
# Block Path:  ['div', 'div6', 'div1']
# Is Leaf:  True
#
# Block Content:  <div2>This page was last edited on 3 April 2025, at 20:07(UTC).</div2>
# Block Path:  ['div', 'div6', 'div2']
# Is Leaf:  True
#
# Block Content:  <div3>Text is available under the <span>Creative Commons Attribution-ShareAlike 4.0 License<span>; additional terms may apply. By using this site, you agree to the</span></span></div3>
# Block Path:  ['div', 'div6', 'div3']
# Is Leaf:  True
#
# Block Content:  <div4>Terms of Use<span> and </span>Privacy Policy<span>. Wikipedia® is a registered trademark of the <span>Wikimedia Foundation, Inc.</span>, a non-profit organization.</span></div4>
# Block Path:  ['div', 'div6', 'div4']
# Is Leaf:  True
#
# Block Content:  <div5>Baseball portal</div5>
# Block Path:  ['div', 'div6', 'div5']
# Is Leaf:  True
#
# Block Content:  <div6>[<span>show</span>]<span>V<span> · <span>T<span> · <span>E</span></span></span></span></span></div6>
# Block Path:  ['div', 'div6', 'div6']
# Is Leaf:  True
#
# Block Content:  <div7>[<span>show</span>]<span>V<span> · <span>T<span> · <span>E</span></span></span></span></span></div7>
# Block Path:  ['div', 'div6', 'div7']
# Is Leaf:  True
#
# Block Content:  <div8>11. <span>^</span> <span>"2018 Modern Baseball Era Ballot"</span> (Press release). National Baseball Hall of Fame and Museum. November</div8>
# Block Path:  ['div', 'div6', 'div8']
# Is Leaf:  True
#
# Block Content:  <div9>6, 2017. Retrieved December 2, 2017.</div9>
# Block Path:  ['div', 'div6', 'div9']
# Is Leaf:  True
#
# Block Content:  <div10>12. ^ </div10>
# Block Path:  ['div', 'div6', 'div10']
# Is Leaf:  True
#
# Block Content:  <div11>a</div11>
# Block Path:  ['div', 'div6', 'div11']
# Is Leaf:  True
#
# Block Content:  <div12>b</div12>
# Block Path:  ['div', 'div6', 'div12']
# Is Leaf:  True
#
# Block Content:  <div13>c</div13>
# Block Path:  ['div', 'div6', 'div13']
# Is Leaf:  True
#
# Block Content:  <div14>d</div14>
# Block Path:  ['div', 'div6', 'div14']
# Is Leaf:  True
#
# Block Content:  <div15>e</div15>
# Block Path:  ['div', 'div6', 'div15']
# Is Leaf:  True
#
# Block Content:  <div16>f</div16>
# Block Path:  ['div', 'div6', 'div16']
# Is Leaf:  True
#
# Block Content:  <div17>g</div17>
# Block Path:  ['div', 'div6', 'div17']
# Is Leaf:  True
#
# Block Content:  <div18>h</div18>
# Block Path:  ['div', 'div6', 'div18']
# Is Leaf:  True
#
# Block Content:  <div19>i</div19>
# Block Path:  ['div', 'div6', 'div19']
# Is Leaf:  True
#
# Block Content:  <div20>j</div20>
# Block Path:  ['div', 'div6', 'div20']
# Is Leaf:  True
#
# Block Content:  <div21> Axisa, Mike (December 10, 2017). <span>"Jack Morris and Alan Trammell voted into Hall of Fame by</span></div21>
# Block Path:  ['div', 'div6', 'div21']
# Is Leaf:  True
#
# Block Content:  <div22>Modern Era Committee"<span>. <span>CBS Sports</span>. Retrieved December 13, 2017.</span></div22>
# Block Path:  ['div', 'div6', 'div22']
# Is Leaf:  True
#
# Block Content:  <div23>13. <span>^</span> <span>"J.G. Taylor Spink Award"<span>. baseball-almanac.com. Retrieved July 20, 2010.</span></span></div23>
# Block Path:  ['div', 'div6', 'div23']
# Is Leaf:  True
#
# Block Content:  <div24>14. <span>^</span> <span>"Awards: J. G. Taylor Spink"<span>. National Baseball Hall of Fame and Museum. Retrieved January 11, 2014.</span></span></div24>
# Block Path:  ['div', 'div6', 'div24']
# Is Leaf:  True
#
# Block Content:  <div25>15. <span>^</span> Miller, Phil (July 11, 2017). <span>"Patrick Reusse nominated for Baseball Hall of Fame honor"</span>. <span>Star Tribune<span>.</span></span></div25>
# Block Path:  ['div', 'div6', 'div25']
# Is Leaf:  True
#
# Block Content:  <div26>Minneapolis<span>. Retrieved December 2, 2017.</span></div26>
# Block Path:  ['div', 'div6', 'div26']
# Is Leaf:  True
#
# Block Content:  <div27>16. <span>^</span> Francis, William (December 12, 2017). <span>"2018 J. G. Taylor Spink Award Winner Sheldon Ocker"<span>.</span></span></div27>
# Block Path:  ['div', 'div6', 'div27']
# Is Leaf:  True
#
# Block Content:  <div28>baseballhall.org<span>. Retrieved December 18, 2017.</span></div28>
# Block Path:  ['div', 'div6', 'div28']
# Is Leaf:  True
#
# Block Content:  <div29>17. <span>^</span> Castrovince, Anthony (December 12, 2017). <span>"Ocker honored as 2018 Spink Award recipient"<span>. </span><span>MLB.com<span>.</span></span></span></div29>
# Block Path:  ['div', 'div6', 'div29']
# Is Leaf:  True
#
# Block Content:  <div30>Retrieved December 13, 2017.</div30>
# Block Path:  ['div', 'div6', 'div30']
# Is Leaf:  True
#
# Block Content:  <div31>18. ^ </div31>
# Block Path:  ['div', 'div6', 'div31']
# Is Leaf:  True
#
# Block Content:  <div32>a</div32>
# Block Path:  ['div', 'div6', 'div32']
# Is Leaf:  True
#
# Block Content:  <div33>b</div33>
# Block Path:  ['div', 'div6', 'div33']
# Is Leaf:  True
#
# Block Content:  <span>"2018 Ford C. Frick Award Ballot"<span> (Press release). National Baseball Hall of Fame and Museum. October</span></span>
# Block Path:  ['div', 'div6', 'span']
# Is Leaf:  True
#
# Block Content:  <div34>23, 2017. Retrieved November 7, 2017.</div34>
# Block Path:  ['div', 'div6', 'div34']
# Is Leaf:  True
#
# Block Content:  <div35>19. <span>^</span> Macklin, Oliver (December 13, 2017). <span>"'National treasure' Costas wins '18 Frick Award"<span>. </span><span>MLB.com<span>. Retrieved</span></span></span></div35>
# Block Path:  ['div', 'div6', 'div35']
# Is Leaf:  True
#
# Block Content:  <div36>December 13, 2017.</div36>
# Block Path:  ['div', 'div6', 'div36']
# Is Leaf:  True
#
# Block Content:  <div37>External links <span>[<span>edit</span>]</span></div37>
# Block Path:  ['div', 'div6', 'div37']
# Is Leaf:  True
#
# Block Content:  <div38>National Baseball Hall of Fame official website</div38>
# Block Path:  ['div', 'div6', 'div38']
# Is Leaf:  True
#
# Block Content:  <div39>BBWAA rules for election to the Hall of Fame</div39>
# Block Path:  ['div', 'div6', 'div39']
# Is Leaf:  True
#
# Block Content:  <div40>Balloting for the <span>National Baseball Hall of Fame</span></div40>
# Block Path:  ['div', 'div6', 'div40']
# Is Leaf:  True
#
# Block Content:  <div41>Baseball Hall of Fame<span> Class of 2018</span></div41>
# Block Path:  ['div', 'div6', 'div41']
# Is Leaf:  True
#
# Block Content:  <div42>Categories<span>: </span>Baseball Hall of Fame balloting2018 in baseball</div42>
# Block Path:  ['div', 'div6', 'div42']
# Is Leaf:  True

# %%
html_1
# Out:
# '\n<div>\n<div0><div0>2018 Baseball Hall of Fame balloting</div0><div1>1 language</div1><div2>Article<span>Talk<span>Read</span>EditView history</span></div2><div3>Tools</div3><div4><div>←\ue662<span>20172019</span>\ue662→</div><div>2018 Baseball Hall of Fame</div><div>balloting</div><div>   National Baseball   </div><div>Hall of Fame and Museum</div><div>New inductees<span>6</span></div><div>via BBWAA<span>4</span></div><div>via Modern Baseball Era</div><div>Committee</div><div>2</div><div>Total inductees<span>323</span></div><div>Induction date<span>July 29, 2018</span></div><div>Key</div><div>\ue662\ue662\ue662\ue662</div><div>Elected to the Hall of Fame on this ballot (named</div><div>in <span>bold italics</span>).</div><div>\ue662\ue662\ue662\ue662</div><div>Elected subsequently, as of 2025 (named in <span>plain</span></div><div>italics<span>).</span></div><div>\ue662\ue662\ue662\ue662</div><div>Renominated for the <span>2019 BBWAA election<span> by</span></span></div><div>adequate performance on this ballot and has not</div><div>subsequently been eliminated.</div><div>\ue662\ue662\ue662\ue662Eliminated from annual BBWAA consideration by</div><div>poor performance or expiration on subsequent</div></div4><div5>From Wikipedia, the free encyclopedia</div5><div6><div>(Redirected from <span>Baseball Hall of Fame balloting, 2018</span>)</div><div>Elections to the <span>National Baseball Hall of Fame</span> for 2018</div><div>proceeded according to rules most recently amended in 2016.</div><div>As in the past, the <span>Baseball Writers\' Association of America</span></div><div>(BBWAA) voted by mail to select from a ballot of recently</div><div>retired players. The results were announced on January 24,</div><div>2018, with the BBWAA electing <span>Chipper Jones</span>, <span>Vladimir</span></div><div>Guerrero<span>, </span>Jim Thome<span> and <span>Trevor Hoffman<span> to the Hall of Fame.</span></span></span></div><div>Jones and Thome were elected in their first year of eligibility.</div><div>[1]</div><div>The three voting panels that replaced the more broadly</div><div>defined <span>Veterans Committee<span> following a 2010 rules change</span></span></div><div>[2]</div><div>were replaced by a new set of four panels in 2016.</div><div>[3]</div><div> The</div><div>Modern Baseball Era Committee<span> convened on December 10,</span></div><div>2017, to select from a ballot of retired players and non-playing personnel who made their greatest</div><div>contributions to the sport between 1970 and 1987,</div><div>[3]</div><div> with <span>Jack Morris</span> and <span>Alan Trammell<span> elected by this</span></span></div><div>body.</div><div>[4]</div><div> The formal induction ceremony was held at the Hall\'s facilities in <span>Cooperstown, New York<span>, on July</span></span></div><div>29, 2018.</div><div>[1]</div><div>BBWAA election <span>[<span>edit</span>]</span></div><div>The BBWAA election rules remained identical to</div><div>those that were in effect for the most recent</div><div>elections. The BBWAA voted at the 2016 winter</div><div>meetings to make all Hall of Fame ballots public</div><div>one week after the results were announced,</div><div>effective with this election.</div><div>[5]</div><div> However, the Hall</div><div>rejected the BBWAA\'s proposal, and ballots remain</div><div>confidential unless individual voters choose to</div><div>reveal them (which is allowed by Hall of Fame</div><div>rules).</div><div>[6]</div><div>DonateCreate accountLog in</div></div6></div0>\n<div1><div>ballots.</div><div>\ue662\ue662\ue662\ue662</div><div>Eliminated from annual BBWAA consideration by</div><div>poor performance or expiration on this ballot.</div><div>†First time on the BBWAA ballot.</div><div>*</div><div>Eliminated from annual BBWAA consideration by</div><div>poor performance on this ballot (not expiration).</div><div>Chipper Jones</div><div>Another recent rules change, announced in 2015,</div><div>tightened the qualification ...

# %% [markdown]
# # Prune HTML Blocks with Embedding Model

# %%
embed_model="BAAI/bge-large-en"
query_instruction_for_retrieval = "Instruct: Given a web search query, retrieve relevant passages that answer the query\nQuery: "
# question = "Given the following HTML content, extract the Hall of Fame voting data as a structured table (Player, Votes, Percent, Change, Year):"

question = """Given two HTML snippets, HTML 1 and HTML 2, do they represent the same table format with the columns "Player", "Votes", "Percent", "Change", and "Year"? If they do, print HTML 1

HTML 1:
<div>PlayerVotesPercentChangeYear</div>
<div>Chipper Jones<span>†<span>41097.2%–1st</span></span></div>
<div>Vladimir Guerrero<span>39292.9%21.2%2nd</span></div>
<div>Jim Thome<span>†<span>37989.8%–1st</span></span></div>
<div>Trevor Hoffman<span>33779.9%5.9%3rd</span></div>
<div>Edgar Martínez<span>29770.4%11.8%9th</span></div>
<div>Mike Mussina<span>26863.5%11.7%5th</span></div>
<div>Roger Clemens<span>24257.3%3.2%6th</span></div>
<div>Barry Bonds<span>23856.4%2.6%6th</span></div>
<div>Curt Schilling<span>21651.2%6.2%6th</span></div>
<div>Omar Vizquel<span>†<span>15637.0%–1st</span></span></div>
<div>Larry Walker<span>14434.1%12.2%8th</span></div>
<div>Fred McGriff<span>9823.2%1.5%9th</span></div>
<div>Manny Ramírez<span>9322.0%1.8%2nd</span></div>
<div>Jeff Kent<span>6114.5%2.2%5th</span></div>
<div>Gary Sheffield<span>4711.1%2.2%4th</span></div>

HTML 2:
<div>Billy Wagner<span>4711.1%0.9%3rd</span></div>
<div>Scott Rolen<span>†<span>4310.2%–1st</span></span></div>
<div>Sammy Sosa<span>337.8%0.8%6th</span></div>
<div>Andruw Jones<span>†<span>317.3%–1st</span></span></div>
<div>Jamie Moyer<span>†*<span>102.4%–1st</span></span></div>
<div>Johan Santana<span>†*<span>102.4%–1st</span></span></div>
<div>Johnny Damon<span>†*<span>81.9%–1st</span></span></div>
<div>Hideki Matsui<span>†*<span>40.9%–1st</span></span></div>
<div>Chris Carpenter<span>†*<span>20.5%–1st</span></span></div>
<div>Kerry Wood<span>†*<span>20.5%–1st</span></span></div>
<div>Liván Hernández<span>†*<span>10.2%–1st</span></span></div>
<div>Carlos Lee<span>†*<span>10.2%–1st</span></span></div>
<div>Orlando Hudson<span>†*<span>00%–1st</span></span></div>
<div>Aubrey Huff<span>†*<span>00%–1st</span></span></div>
<div>Jason Isringhausen<span>†*<span>00%–1st</span></span></div>
<div>Brad Lidge<span>†*<span>00%–1st</span></span></div>
<div>Kevin Millwood<span>†*<span>00%–1st</span></span></div>
<div>Carlos Zambrano<span>†*<span>00%–1st</span></span></div>
"""

# %%
embed_model="BAAI/bge-large-en"
query_instruction_for_retrieval = "Instruct: Given a web search query, retrieve relevant passages that answer the query\nQuery: "
embed_html_pruner = EmbedHTMLPruner(embed_model=embed_model, local_inference=True, query_instruction_for_retrieval = query_instruction_for_retrieval)
# alternatively you can init a remote TEI model, refer to https://github.com/huggingface/text-embeddings-inference.
# tei_endpoint="http://YOUR_TEI_ENDPOINT"
# embed_html_pruner = EmbedHTMLPruner(embed_model=embed_model, local_inference=False, query_instruction_for_retrieval = query_instruction_for_retrieval, endpoint=tei_endpoint)
block_rankings=embed_html_pruner.calculate_block_rankings(question, html_1, block_1)
print(block_rankings)
# Out:
# [1, 132, 0, 109, 99, 138, 128, 97, 92, 103, 129, 140, 144, 112, 145, 127, 2, 101, 96, 78, 102, 95, 146, 76, 3, 143, 93, 68, 126, 147, 12, 39, 17, 29, 86, 22, 133, 7, 84, 117, 5, 73, 74, 82, 89, 115, 136, 50, 122, 98, 104, 107, 24, 4, 8, 55, 125, 38, 20, 121, 131, 49, 31, 120, 85, 118, 62, 28, 75, 83, 90, 116, 137, 66, 79, 80, 33, 18, 52, 64, 23, 53, 123, 71, 60, 94, 70, 119, 81, 134, 44, 139, 142, 124, 58, 114, 72, 54, 6, 130, 88, 135, 65, 105, 14, 9, 91, 41, 45, 100, 87, 110, 111, 46, 113, 10, 35, 106, 13, 30, 56, 26, 108, 36, 63, 57, 59, 25, 11, 34, 37, 77, 141, 61, 42, 21, 43, 27, 32, 47, 19, 40, 15, 51, 16, 69, 48, 67]

# %%
bm25_html_pruner = BM25HTMLPruner()
block_rankings = bm25_html_pruner.calculate_block_rankings(question, html_1, block_1)
print(block_rankings)
# Out:
# [4, 48, 37, 15, 43, 130, 61, 113, 9, 47, 11, 10, 79, 49, 108, 14, 67, 2, 98, 7, 0, 92, 86, 62, 125, 138, 34, 112, 36, 128, 32, 27, 8, 66, 41, 12, 69, 22, 18, 65, 51, 1, 13, 26, 145, 107, 144, 21, 16, 42, 25, 35, 40, 95, 68, 38, 39, 114, 115, 116, 117, 118, 119, 120, 33, 44, 45, 46, 50, 52, 53, 54, 55, 121, 94, 96, 97, 3, 5, 6, 143, 146, 17, 131, 132, 30, 134, 122, 123, 124, 126, 127, 129, 28, 29, 56, 31, 133, 78, 80, 81, 82, 83, 84, 85, 87, 88, 89, 90, 57, 142, 136, 137, 19, 20, 23, 24, 147, 93, 135, 139, 140, 91, 141, 58, 59, 60, 63, 64, 106, 109, 110, 111, 70, 77, 72, 73, 99, 100, 101, 102, 103, 104, 105, 74, 75, 76, 71]

# %%
os.environ["HF_TOKEN"] = "tự create mà dùng nha"
token = os.environ.get("HF_TOKEN")

if token:
    print("Token successfully retrieved!")
else:
    print("Token not found!")
# Out:
# Token successfully retrieved!

# %%
chat_tokenizer = AutoTokenizer.from_pretrained("meta-llama/Llama-3.1-70B-Instruct",  token=token)

pruned_html = embed_html_pruner.prune_HTML(html_1, block_1, block_rankings, chat_tokenizer, MAX_CONTEXT_WINDOW_EMBED)
print(pruned_html)
# Out:
# <div>
# <div0><div0>2018 Baseball Hall of Fame balloting</div0><div1>1 language</div1><div4><div>←<span>20172019</span>→</div><div>2018 Baseball Hall of Fame</div><div>balloting</div><div>   National Baseball   </div><div>Hall of Fame and Museum</div><div>New inductees<span>6</span></div><div>via BBWAA<span>4</span></div><div>via Modern Baseball Era</div><div>Committee</div><div>2</div><div>Total inductees<span>323</span></div><div>Induction date<span>July 29, 2018</span></div><div>Key</div><div></div><div>Elected to the Hall of Fame on this ballot (named</div><div>in <span>bold italics</span>).</div><div></div><div>Elected subsequently, as of 2025 (named in <span>plain</span></div><div>italics<span>).</span></div><div></div><div>Renominated for the <span>2019 BBWAA election<span> by</span></span></div><div>adequate performance on this ballot and has not</div><div>subsequently been eliminated.</div><div>Eliminated from annual BBWAA consideration by</div><div>poor performance or expiration on subsequent</div></div4><div5>From Wikipedia, the free encyclopedia</div5><div6><div>(Redirected from <span>Baseball Hall of Fame balloting, 2018</span>)</div><div>Elections to the <span>National Baseball Hall of Fame</span> for 2018</div><div>proceeded according to rules most recently amended in 2016.</div><div>As in the past, the <span>Baseball Writers' Association of America</span></div><div>(BBWAA) voted by mail to select from a ballot of recently</div><div>retired players. The results were announced on January 24,</div><div>2018, with the BBWAA electing <span>Chipper Jones</span>, <span>Vladimir</span></div><div>Guerrero<span>, </span>Jim Thome<span> and <span>Trevor Hoffman<span> to the Hall of Fame.</span></span></span></div><div>Jones and Thome were elected in their first year of eligibility.</div><div>[1]</div><div>The three voting panels that replaced the more broadly</div><div>defined <span>Veterans Committee<span> following a 2010 rules change</span></span></div><div>[2]</div><div>were replaced by a new set of four panels in 2016.</div><div>[3]</div><div> The</div><div>Modern Baseball Era Committee<span> convened on December 10,</span></div><div>2017, to select from a ballot of retired players and non-playing personnel who made their greatest</div><div>contributions to the sport between 1970 and 1987,</div><div>[3]</div><div> with <span>Jack Morris</span> and <span>Alan Trammell<span> elected by this</span></span></div><div>body.</div><div>[4]</div><div> The formal induction ceremony was held at the Hall's facilities in <span>Cooperstown, New York<span>, on July</span></span></div><div>29, 2018.</div><div>[1]</div><div>BBWAA election <span>[<span>edit</span>]</span></div><div>The BBWAA election rules remained identical to</div><div>those that were in effect for the most recent</div><div>elections. The BBWAA voted at the 2016 winter</div><div>meetings to make all Hall of Fame ballots public</div><div>one week after the results were announced,</div><div>effective with this election.</div><div>[5]</div><div> However, the Hall</div><div>rejected the BBWAA's proposal, and ballots remain</div><div>confidential unless individual voters choose to</div><div>reveal them (which is allowed by Hall of Fame</div><div>rules).</div><div>[6]</div><div>DonateCreate accountLog in</div></div6></div0>
# <div1><div>ballots.</div><div></div><div>Eliminated from annual BBWAA consideration by</div><div>poor performance or expiration on this ballot.</div><div>†First time on the BBWAA ballot.</div><div>*</div><div>Eliminated from annual BBWAA consideration by</div><div>poor performance on this ballot (not expiration).</div><div>Chipper Jones</div><div>Another recent rules change, announced in 2015,</div><div>tightened the qualifications for the BBWAA</div><div>electorate. Beginning with the 2016 election,</div><div>eligible voters must not only have 10years of</div><div>continuous BBWAA membership, but also be</div><div>currently active members, or have held active</div><div>status within the 10years prior to the election. A</div><div>BBWAA member who has not been active for more</div><div>than 10years can regain voting status by covering MLB in the year preceding the election.</div><div>[7]</div><div> As a result of</div><div>the new rule, the vote total in 2016 decreased by 109 from the previous year, to 440.</div><div>[8]</div><div>The ballot included two categories of players:</div><div>Candidates from the 2017 ballot who received at least 5% of the vote but were not elected, as long as</div><div>they first appeared on the BBWAA ballot no earlier than 2009.</div><div>Selected individuals, chosen by a screening committee, whose last MLB appearance was in 2012.</div><div>422 ballots were cast, 20 fewer than in 2017. There were 422 ballots cast, with a total of 3570 votes for</div><div>individual players, an average of 8.46 names per ballot—the highest per-ballot average since 1960 (8.51</div><div>votes per ballot).</div><div>Voting results from 2018:</div><div>[9]</div><div>PlayerVotesPercentChangeYear</div><div>Chipper Jones<span>†<span>41097.2%–1st</span></span></div><div>Vladimir Guerrero<span>39292.9%21.2%2nd</span></div><div>Jim Thome<span>†<span>37989.8%–1st</span></span></div><div>Trevor Hoffman<span>33779.9%5.9%3rd</span></div><div>Edgar Martínez<span>29770.4%11.8%9th</span></div><div>Mike Mussina<span>26863.5%11.7%5th</span></div><div>Roger Clemens<span>24257.3%3.2%6th</span></div><div>Barry Bonds<span>23856.4%2.6%6th</span></div><div>Curt Schilling<span>21651.2%6.2%6th</span></div><div>Omar Vizquel<span>†<span>15637.0%–1st</span></span></div><div>Larry Walker<span>14434.1%12.2%8th</span></div><div>Fred McGriff<span>9823.2%1.5%9th</span></div><div>Manny Ramírez<span>9322.0%1.8%2nd</span></div><div>Jeff Kent<span>6114.5%2.2%5th</span></div><div>Gary Sheffield<span>4711.1%2.2%4th</span></div></div1>
# <div2><div>Vladimir Guerrero</div><div>Jim Thome</div><div>Trevor Hoffman</div><div>Billy Wagner<span>4711.1%0.9%3rd</span></div><div>Scott Rolen<span>†<span>4310.2%–1st</span></span></div><div>Sammy Sosa<span>337.8%0.8%6th</span></div><div>Andruw Jones<span>†<span>317.3%–1st</span></span></div><div>Jamie Moyer<span>†*<span>102.4%–1st</span></span></div><div>Johan Santana<span>†*<span>102.4%–1st</span></span></div><div>Johnny Damon<span>†*<span>81.9%–1st</span></span></div><div>Hideki Matsui<span>†*<span>40.9%–1st</span></span></div><div>Chris Carpenter<span>†*<span>20.5%–1st</span></span></div><div>Kerry Wood<span>†*<span>20.5%–1st</span></span></div><div>Liván Hernández<span>†*<span>10.2%–1st</span></span></div><div>Carlos Lee<span>†*<span>10.2%–1st</span></span></div><div>Orlando Hudson<span>†*<span>00%–1st</span></span></div><div>Aubrey Huff<span>†*<span>00%–1st</span></span></div><div>Jason Isringhausen<span>†*<span>00%–1st</span></span></div><div>Brad Lidge<span>†*<span>00%–1st</span></span></div><div>Kevin Millwood<span>†*<span>00%–1st</span></span></div><div>Carlos Zambrano<span>†*<span>00%–1st</span></span></div><div>Players who were eligible for the first time in 2018 but were <span>not</span> on</div><div>the ballot included <span>Rod Barajas</span>, <span>Miguel Batista</span>, <span>Geoff Blum</span>, <span>Miguel</span></div><div>Cairo<span>, <span>Aaron Cook<span>, </span>Francisco Cordero<span>, </span>Juan Cruz<span>, </span>Brian Fuentes<span>,</span></span></span></div><div>Bill Hall<span>, </span>Willie Harris<span>, </span>Nick Johnson<span>, <span>Adam Kennedy<span>, <span>Rodrigo</span></span></span></span></div><div>López<span>, </span>Mike MacDougal<span>, </span>Guillermo Mota<span>, </span>Will Ohman<span>, </span>Vicente</div><div>Padilla<span>, </span>Carl Pavano<span>, </span>Scott Podsednik<span>, </span>Juan Rivera<span>, </span>J. C. Romero<span>,</span></div><div>Brian Schneider<span>, <span>Ben Sheets</span>, <span>Jeff Suppan</span>, <span>Kip Wells</span>, <span>Dan Wheeler</span></span></div><div>and <span>Jack Wilson</span>.</div><div>Scott Rolen's 10.2% was the lowest first-year vote percentage in</div><div>history for a candidate who was eventually elected by the BBWAA.</div><div>He was voted in on the <span>2023 ballot</span>.</div><div>[10]</div><div>Modern Baseball Era Committee <span>[<span>edit</span>]</span></div><div>On July 23, 2016, the Hall of Fame announced changes to the Era Committee system. The system's</div><div>timeframes were restructured to place a greater emphasis on the modern game, and to reduce the</div></div2>
# <div3><div>Jack Morris</div><div>Alan Trammell</div><div>frequency at which individuals from the pre-1970 game (including</div><div>Negro league baseball<span> figures) will have their careers reviewed.</span></div><div>[3]</div><div>Considering candidates whose greatest contributions occurred from</div><div>1970 to 1987, the Modern Baseball Era Committee met in 2017 as</div><div>part of the elections for the next calendar year.</div><div>Further information: <span>Veterans Committee §2016 revisions</span></div><div>On November 6, 2017, the Hall announced the 10 candidates to be</div><div>considered when the Modern Baseball Era Committee met at the</div><div>2017 winter meetings near <span>Walt Disney World<span> on December 10, with</span></span></div><div>the voting results announced immediately after the committee</div><div>met.</div><div>[11]</div><div> The cutoff for election and induction remained the standard</div><div>75%, or 12 of 16 votes.</div><div>The committee consisted of the following individuals:</div><div>[4]</div><div>Hall of Famers: <span>George Brett</span>, <span>Rod Carew<span>, <span>Bobby Cox</span>, <span>Dennis</span></span></span></div><div>Eckersley<span>, <span>John Schuerholz</span>, <span>Don Sutton</span>, <span>Dave Winfield</span>, <span>Robin</span></span></div><div>Yount</div><div>Executives: <span>Sandy Alderson<span>, </span>Paul Beeston<span>, </span>Bob Castellini<span>, </span>David</span></div><div>Glass<span>, </span>Bill DeWitt</div><div>Media and historians: <span>Bob Elliott</span>, <span>Steve Hirdt</span>, <span>Jayson Stark</span></div><div>Non-voting committee chair: Jane Forbes Clark (Hall of Fame</div><div>chairman)</div><div>CandidateCategoryVotesPercentRef</div><div>Jack Morris<span>Player1487.5%</span></div><div>[12]</div><div>Alan Trammell<span>Player1381.3%</span></div><div>[12]</div><div>Ted Simmons<span>Player1168.8%</span></div><div>[12]</div><div>Marvin Miller<span>Executive743.8%</span></div><div>[12]</div><div>Steve Garvey<span>Player&lt;7–</span></div><div>[12]</div><div>Tommy John<span>Player&lt;7–</span></div><div>[12]</div><div>Don Mattingly<span>Player&lt;7–</span></div><div>[12]</div><div>Dale Murphy<span>Player&lt;7–</span></div><div>[12]</div><div>Dave Parker<span>Player&lt;7–</span></div><div>[12]</div><div>Luis Tiant<span>Player&lt;7–</span></div><div>[12]</div><div>All candidates except Miller were living when the ballot and voting results were announced. Mattingly,</div><div>Morris, Murphy and Trammell were being considered for the first time; the others had been considered at</div></div3>
# <div4><div0>least once by one of the predecessors to this committee. Garvey, John, Miller, Parker and Simmons were</div0><div1>most recently considered in 2014 by the former Expansion Era Committee, and Tiant was most recently</div1><div2>considered by the former Golden Era Committee in 2015. Among players, Simmons was the only candidate</div2><div3>who was not on the BBWAA ballot for the full 15-year period formerly allowed by Hall rules; he received less</div3><div4>than 5% when he debuted on the BBWAA ballot in 1994 and thus did not appear on further ballots. The Hall</div4><div5>changed the eligibility period to 10 years starting with the 2015 election, but Trammell and Mattingly (who</div5><div6>were then past the new 10-year cutoff) retained their original 15-year eligibility window.</div6><div8>The <span>J. G. Taylor Spink Award<span> has been presented by the BBWAA at the annual summer induction</span></span></div8><div11> Through 2010, it was awarded during the main induction ceremony, but is now</div11><div12>given the previous day at the Hall of Fame Awards Presentation. It recognizes a <span>sportswriter</span> "for meritorious</div12><div15> The recipients are not members of the Hall of Fame but are featured in</div15><div16>a permanent exhibit at the National Baseball Museum.</div16><div17>The three finalists for the 2018 award were announced during the 2017 <span>All-Star<span> break.</span></span></div17><div22>Ocker was announced as the recipient during the 2017 winter meetings on December 12.</div22><div23>[16]</div23><div24> He covered the</div24><div25>Cleveland Indians for more than three decades, serving as Cleveland Indians beat reporter for the <span>Beacon-</span></div25><div26>Journal<span> from 1981 until his retirement at the end of the 2013 season. Ocker received 168 of the 426 ballots</span></div26><div27>cast (including two blanks) to Reeves' 143 and Reusse's 113.</div27><div28>[17]</div28><div29>Ford C. Frick Award <span>[<span>edit</span>]</span></div29><div30>Various changes in July 2016 were also made to the annual <span>Ford C. Frick Award<span> elections, presented</span></span></div30><div31>annually to a preeminent baseball broadcaster since 1978. According to the Hall, the new criteria for</div31><div32>selection are "Commitment to excellence, quality of broadcasting abilities, reverence within the game,</div32><div33>popularity with fans, and recognition by peers."</div33><div34>Additionally, a ballot of eight candidates will now be set, down from 10 in years past. The three ballot slots</div34><div35>previously determined by fan voting on <span>Facebook</span> will now be filled by a committee of historians.</div35><div36>A new election cycle has been established, rotating annually between <span>Current Major League Markets</span> (team-</div36><div37>specific announcers) with the 2017 Frick Award; <span>National Voices<span> (broadcasters whose contributions were</span></span></div37><div38>realized on a national level) with the 2018 Frick Award; and <span>Broadcasting Beginnings</span> (early team voices and</div38><div39>pioneers of baseball broadcasting) with the 2019 Frick Award. This cycle will repeat every three years.</div39><div40>[3]</div40><div41>The Hall announced the following finalists for the 2018 Ford C. Frick Award on October 23, 2017.</div41><div42>[18]</div42></div4>
# <div5><div0>Buddy Blattner</div0><div1>Joe Buck</div1><div2>Bob Costas</div2><div5>Al Michaels</div5><div6>Joe Morgan</div6><div7>Pee Wee Reese</div7><div8>Four finalists were members of the Hall of Fame as players—Dean, Drysdale, Morgan and Reese. When the</div8><div9>ballot was announced, Buck, Costas, Michaels and Morgan were still alive. The other four were</div9><div10>deceased.</div10><div11>[18]</div11><div12>Costas was announced as the recipient at the 2017 winter meetings on December 13. He began his</div12><div13>sportscasting career as a play-by-play caller for the <span>Spirits of St. Louis</span> in the <span>American Basketball</span></div13><div14>Association<span>, and went from there to calling </span>NBA<span> and <span>NFL</span> games for <span>CBS</span>, but made his greatest mark as</span></div14><div15>part of <span>NBC</span>'s broadcast team for its national MLB telecasts from 1982 to 2009. Costas then joined the <span>MLB</span></div15><div16>Network<span>, where he was serving as the network's documentary host when he was announced as the Frick</span></div16><div17>Award recipient.</div17><div18>[19]</div18><div19>References <span>[<span>edit</span>]</span></div19><div20>1. ^ </div20><div21>a</div21><div22>b</div22><div23> <span>"Baseball Hall of Fame adds four new members"</span>. <span>ESPN.com</span>. January 24, 2018. Retrieved January 24,</div23><div24>2018.</div24><div26>and Long-Retired Players"<span> (Press release). National Baseball Hall of Fame and Museum. July 26, 2010.</span></div26> <span0>"Hall of Fame Makes Series of Announcements"<span> (Press release). National Baseball Hall of Fame and</span></span0> <span1>"Jack Morris, Alan Trammell Elected to Hall of Fame by Modern Baseball Era Committee"<span> (Press release).</span></span1><div37>National Baseball Hall of Fame and Museum. December 10, 2017. Retrieved December 10, 2017.</div37><div38>5. <span>^</span> Bloom, Barry J. (December 6, 2016). <span>"Hall of Fame ballots will be made public starting in 2018"<span>. mlb.com.</span></span></div38><div39>Retrieved January 18, 2017.</div39><div40>6. <span>^</span> Calcaterra, Craig (November 20, 2017). <span>"The Hall of Fame rejected the BBWAA vote to make ballots public"<span>.</span></span></div40><div41>NBC Sports. Retrieved December 11, 2017.</div41><div42>7. <span>^</span> <span>"Hall of Fame Announces Change to BBWAA Voting Electorate"<span> (Press release). National Baseball Hall of</span></span></div42><div43>Fame and Museum. July 28, 2015. Retrieved July 28, 2015.</div43><div44>8. <span>^</span> <span>"Ken Griffey Jr. (99 percent of vote), Mike Piazza head to Cooperstown"<span>. espn.go.com. January 6, 2016.</span></span></div44><div45>Retrieved January 6, 2016.</div45><div46>9. <span>^</span> Baseball Hall of Fame. <span>"BBWAA elects 4 to Hall of Fame"<span>.</span></span></div46><div47>10. <span>^</span> Axisa, Mike (January 24, 2022). <span>"2023 Baseball Hall of Fame voting results: Scott Rolen squeaks in, will join</span></div47><div48>Fred McGriff in Cooperstown"<span>. <span>CBSSports.com</span>. Retrieved January 24, 2022.</span></div48></div5>
# <div6><div0>Privacy policyAbout WikipediaDisclaimersContact WikipediaCode of ConductDevelopersStatisticsCookie statement</div0><div1>Mobile view</div1><div2>This page was last edited on 3 April 2025, at 20:07(UTC).</div2><div3>Text is available under the <span>Creative Commons Attribution-ShareAlike 4.0 License<span>; additional terms may apply. By using this site, you agree to the</span></span></div3><div4>Terms of Use<span> and </span>Privacy Policy<span>. Wikipedia® is a registered trademark of the <span>Wikimedia Foundation, Inc.</span>, a non-profit organization.</span></div4><div5>Baseball portal</div5><div6>[<span>show</span>]<span>V<span> · <span>T<span> · <span>E</span></span></span></span></span></div6><div7>[<span>show</span>]<span>V<span> · <span>T<span> · <span>E</span></span></span></span></span></div7><div8>11. <span>^</span> <span>"2018 Modern Baseball Era Ballot"</span> (Press release). National Baseball Hall of Fame and Museum. November</div8><div9>6, 2017. Retrieved December 2, 2017.</div9><div10>12. ^ </div10><div11>a</div11><div12>b</div12><div13>c</div13><div14>d</div14><div15>e</div15><div16>f</div16><div17>g</div17><div21> Axisa, Mike (December 10, 2017). <span>"Jack Morris and Alan Trammell voted into Hall of Fame by</span></div21><div24>14. <span>^</span> <span>"Awards: J. G. Taylor Spink"<span>. National Baseball Hall of Fame and Museum. Retrieved January 11, 2014.</span></span></div24><div26>Minneapolis<span>. Retrieved December 2, 2017.</span></div26><div31>18. ^ </div31> <span>"2018 Ford C. Frick Award Ballot"<span> (Press release). National Baseball Hall of Fame and Museum. October</span></span><div34>23, 2017. Retrieved November 7, 2017.</div34><div35>19. <span>^</span> Macklin, Oliver (December 13, 2017). <span>"'National treasure' Costas wins '18 Frick Award"<span>. </span><span>MLB.com<span>. Retrieved</span></span></span></div35><div36>December 13, 2017.</div36><div39>BBWAA rules for election to the Hall of Fame</div39><div40>Balloting for the <span>National Baseball Hall of Fame</span></div40></div6>
# </div>

# %% [markdown]
# # Prune HTML Blocks with Generative Model

# %%
# construct a finer block tree
block_2, pruned_html = build_block_tree(pruned_html, max_node_words=MAX_NODE_WORDS_GEN)
# block_tree, pruned_html = build_block_tree(pruned_html, max_node_words=MAX_NODE_WORDS_GEN, zh_char=True) # for Chinese text
for block in block_2:
    print("Block Content: ", block[0])
    print("Block Path: ", block[1])
    print("Is Leaf: ", block[2])
    print("")
# Out:
# Block Content:  <div0>2018 Baseball Hall of Fame balloting</div0>
# Block Path:  ['div', 'div0', 'div0']
# Is Leaf:  True
#
# Block Content:  <div1>1 language</div1>
# Block Path:  ['div', 'div0', 'div1']
# Is Leaf:  True
#
# Block Content:  <div4><div>←<span>20172019</span>→</div><div>2018 Baseball Hall of Fame</div><div>balloting</div><div>   National Baseball   </div><div>Hall of Fame and Museum</div><div>New inductees<span>6</span></div><div>via BBWAA<span>4</span></div><div>via Modern Baseball Era</div><div>Committee</div><div>2</div><div>Total inductees<span>323</span></div><div>Induction date<span>July 29, 2018</span></div><div>Key</div><div></div><div>Elected to the Hall of Fame on this ballot (named</div><div>in <span>bold italics</span>).</div><div></div><div>Elected subsequently, as of 2025 (named in <span>plain</span></div><div>italics<span>).</span></div><div></div><div>Renominated for the <span>2019 BBWAA election<span> by</span></span></div><div>adequate performance on this ballot and has not</div><div>subsequently been eliminated.</div><div>Eliminated from annual BBWAA consideration by</div><div>poor performance or expiration on subsequent</div></div4>
# Block Path:  ['div', 'div0', 'div4']
# Is Leaf:  True
#
# Block Content:  <div5>From Wikipedia, the free encyclopedia</div5>
# Block Path:  ['div', 'div0', 'div5']
# Is Leaf:  True
#
# Block Content:  <div0>ballots.</div0>
# Block Path:  ['div', 'div1', 'div0']
# Is Leaf:  True
#
# Block Content:  <div1></div1>
# Block Path:  ['div', 'div1', 'div1']
# Is Leaf:  True
#
# Block Content:  <div2>Eliminated from annual BBWAA consideration by</div2>
# Block Path:  ['div', 'div1', 'div2']
# Is Leaf:  True
#
# Block Content:  <div3>poor performance or expiration on this ballot.</div3>
# Block Path:  ['div', 'div1', 'div3']
# Is Leaf:  True
#
# Block Content:  <div4>†First time on the BBWAA ballot.</div4>
# Block Path:  ['div', 'div1', 'div4']
# Is Leaf:  True
#
# Block Content:  <div5>*</div5>
# Block Path:  ['div', 'div1', 'div5']
# Is Leaf:  True
#
# Block Content:  <div6>Eliminated from annual BBWAA consideration by</div6>
# Block Path:  ['div', 'div1', 'div6']
# Is Leaf:  True
#
# Block Content:  <div7>poor performance on this ballot (not expiration).</div7>
# Block Path:  ['div', 'div1', 'div7']
# Is Leaf:  True
#
# Block Content:  <div8>Chipper Jones</div8>
# Block Path:  ['div', 'div1', 'div8']
# Is Leaf:  True
#
# Block Content:  <div9>Another recent rules change, announced in 2015,</div9>
# Block Path:  ['div', 'div1', 'div9']
# Is Leaf:  True
#
# Block Content:  <div10>tightened the qualifications for the BBWAA</div10>
# Block Path:  ['div', 'div1', 'div10']
# Is Leaf:  True
#
# Block Content:  <div11>electorate. Beginning with the 2016 election,</div11>
# Block Path:  ['div', 'div1', 'div11']
# Is Leaf:  True
#
# Block Content:  <div12>eligible voters must not only have 10years of</div12>
# Block Path:  ['div', 'div1', 'div12']
# Is Leaf:  True
#
# Block Content:  <div13>continuous BBWAA membership, but also be</div13>
# Block Path:  ['div', 'div1', 'div13']
# Is Leaf:  True
#
# Block Content:  <div14>currently active members, or have held active</div14>
# Block Path:  ['div', 'div1', 'div14']
# Is Leaf:  True
#
# Block Content:  <div15>status within the 10years prior to the election. A</div15>
# Block Path:  ['div', 'div1', 'div15']
# Is Leaf:  True
#
# Block Content:  <div16>BBWAA member who has not been active for more</div16>
# Block Path:  ['div', 'div1', 'div16']
# Is Leaf:  True
#
# Block Content:  <div17>than 10years can regain voting status by covering MLB in the year preceding the election.</div17>
# Block Path:  ['div', 'div1', 'div17']
# Is Leaf:  True
#
# Block Content:  <div18>[7]</div18>
# Block Path:  ['div', 'div1', 'div18']
# Is Leaf:  True
#
# Block Content:  <div19> As a result of</div19>
# Block Path:  ['div', 'div1', 'div19']
# Is Leaf:  True
#
# Block Content:  <div20>the new rule, the vote total in 2016 decreased by 109 from the previous year, to 440.</div20>
# Block Path:  ['div', 'div1', 'div20']
# Is Leaf:  True
#
# Block Content:  <div21>[8]</div21>
# Block Path:  ['div', 'div1', 'div21']
# Is Leaf:  True
#
# Block Content:  <div22>The ballot included two categories of players:</div22>
# Block Path:  ['div', 'div1', 'div22']
# Is Leaf:  True
#
# Block Content:  <div23>Candidates from the 2017 ballot who received at least 5% of the vote but were not elected, as long as</div23>
# Block Path:  ['div', 'div1', 'div23']
# Is Leaf:  True
#
# Block Content:  <div24>they first appeared on the BBWAA ballot no earlier than 2009.</div24>
# Block Path:  ['div', 'div1', 'div24']
# Is Leaf:  True
#
# Block Content:  <div25>Selected individuals, chosen by a screening committee, whose last MLB appearance was in 2012.</div25>
# Block Path:  ['div', 'div1', 'div25']
# Is Leaf:  True
#
# Block Content:  <div26>422 ballots were cast, 20 fewer than in 2017. There were 422 ballots cast, with a total of 3570 votes for</div26>
# Block Path:  ['div', 'div1', 'div26']
# Is Leaf:  True
#
# Block Content:  <div27>individual players, an average of 8.46 names per ballot—the highest per-ballot average since 1960 (8.51</div27>
# Block Path:  ['div', 'div1', 'div27']
# Is Leaf:  True
#
# Block Content:  <div28>votes per ballot).</div28>
# Block Path:  ['div', 'div1', 'div28']
# Is Leaf:  True
#
# Block Content:  <div29>Voting results from 2018:</div29>
# Block Path:  ['div', 'div1', 'div29']
# Is Leaf:  True
#
# Block Content:  <div30>[9]</div30>
# Block Path:  ['div', 'div1', 'div30']
# Is Leaf:  True
#
# Block Content:  <div31>PlayerVotesPercentChangeYear</div31>
# Block Path:  ['div', 'div1', 'div31']
# Is Leaf:  True
#
# Block Content:  <div32>Chipper Jones<span>†<span>41097.2%–1st</span></span></div32>
# Block Path:  ['div', 'div1', 'div32']
# Is Leaf:  True
#
# Block Content:  <div33>Vladimir Guerrero<span>39292.9%21.2%2nd</span></div33>
# Block Path:  ['div', 'div1', 'div33']
# Is Leaf:  True
#
# Block Content:  <div34>Jim Thome<span>†<span>37989.8%–1st</span></span></div34>
# Block Path:  ['div', 'div1', 'div34']
# Is Leaf:  True
#
# Block Content:  <div35>Trevor Hoffman<span>33779.9%5.9%3rd</span></div35>
# Block Path:  ['div', 'div1', 'div35']
# Is Leaf:  True
#
# Block Content:  <div36>Edgar Martínez<span>29770.4%11.8%9th</span></div36>
# Block Path:  ['div', 'div1', 'div36']
# Is Leaf:  True
#
# Block Content:  <div37>Mike Mussina<span>26863.5%11.7%5th</span></div37>
# Block Path:  ['div', 'div1', 'div37']
# Is Leaf:  True
#
# Block Content:  <div38>Roger Clemens<span>24257.3%3.2%6th</span></div38>
# Block Path:  ['div', 'div1', 'div38']
# Is Leaf:  True
#
# Block Content:  <div39>Barry Bonds<span>23856.4%2.6%6th</span></div39>
# Block Path:  ['div', 'div1', 'div39']
# Is Leaf:  True
#
# Block Content:  <div40>Curt Schilling<span>21651.2%6.2%6th</span></div40>
# Block Path:  ['div', 'div1', 'div40']
# Is Leaf:  True
#
# Block Content:  <div41>Omar Vizquel<span>†<span>15637.0%–1st</span></span></div41>
# Block Path:  ['div', 'div1', 'div41']
# Is Leaf:  True
#
# Block Content:  <div42>Larry Walker<span>14434.1%12.2%8th</span></div42>
# Block Path:  ['div', 'div1', 'div42']
# Is Leaf:  True
#
# Block Content:  <div43>Fred McGriff<span>9823.2%1.5%9th</span></div43>
# Block Path:  ['div', 'div1', 'div43']
# Is Leaf:  True
#
# Block Content:  <div44>Manny Ramírez<span>9322.0%1.8%2nd</span></div44>
# Block Path:  ['div', 'div1', 'div44']
# Is Leaf:  True
#
# Block Content:  <div45>Jeff Kent<span>6114.5%2.2%5th</span></div45>
# Block Path:  ['div', 'div1', 'div45']
# Is Leaf:  True
#
# Block Content:  <div46>Gary Sheffield<span>4711.1%2.2%4th</span></div46>
# Block Path:  ['div', 'div1', 'div46']
# Is Leaf:  True
#
# Block Content:  <div0>Vladimir Guerrero</div0>
# Block Path:  ['div', 'div2', 'div0']
# Is Leaf:  True
#
# Block Content:  <div1>Jim Thome</div1>
# Block Path:  ['div', 'div2', 'div1']
# Is Leaf:  True
#
# Block Content:  <div2>Trevor Hoffman</div2>
# Block Path:  ['div', 'div2', 'div2']
# Is Leaf:  True
#
# Block Content:  <div3>Billy Wagner<span>4711.1%0.9%3rd</span></div3>
# Block Path:  ['div', 'div2', 'div3']
# Is Leaf:  True
#
# Block Content:  <div4>Scott Rolen<span>†<span>4310.2%–1st</span></span></div4>
# Block Path:  ['div', 'div2', 'div4']
# Is Leaf:  True
#
# Block Content:  <div5>Sammy Sosa<span>337.8%0.8%6th</span></div5>
# Block Path:  ['div', 'div2', 'div5']
# Is Leaf:  True
#
# Block Content:  <div6>Andruw Jones<span>†<span>317.3%–1st</span></span></div6>
# Block Path:  ['div', 'div2', 'div6']
# Is Leaf:  True
#
# Block Content:  <div7>Jamie Moyer<span>†*<span>102.4%–1st</span></span></div7>
# Block Path:  ['div', 'div2', 'div7']
# Is Leaf:  True
#
# Block Content:  <div8>Johan Santana<span>†*<span>102.4%–1st</span></span></div8>
# Block Path:  ['div', 'div2', 'div8']
# Is Leaf:  True
#
# Block Content:  <div9>Johnny Damon<span>†*<span>81.9%–1st</span></span></div9>
# Block Path:  ['div', 'div2', 'div9']
# Is Leaf:  True
#
# Block Content:  <div10>Hideki Matsui<span>†*<span>40.9%–1st</span></span></div10>
# Block Path:  ['div', 'div2', 'div10']
# Is Leaf:  True
#
# Block Content:  <div11>Chris Carpenter<span>†*<span>20.5%–1st</span></span></div11>
# Block Path:  ['div', 'div2', 'div11']
# Is Leaf:  True
#
# Block Content:  <div12>Kerry Wood<span>†*<span>20.5%–1st</span></span></div12>
# Block Path:  ['div', 'div2', 'div12']
# Is Leaf:  True
#
# Block Content:  <div13>Liván Hernández<span>†*<span>10.2%–1st</span></span></div13>
# Block Path:  ['div', 'div2', 'div13']
# Is Leaf:  True
#
# Block Content:  <div14>Carlos Lee<span>†*<span>10.2%–1st</span></span></div14>
# Block Path:  ['div', 'div2', 'div14']
# Is Leaf:  True
#
# Block Content:  <div15>Orlando Hudson<span>†*<span>00%–1st</span></span></div15>
# Block Path:  ['div', 'div2', 'div15']
# Is Leaf:  True
#
# Block Content:  <div16>Aubrey Huff<span>†*<span>00%–1st</span></span></div16>
# Block Path:  ['div', 'div2', 'div16']
# Is Leaf:  True
#
# Block Content:  <div17>Jason Isringhausen<span>†*<span>00%–1st</span></span></div17>
# Block Path:  ['div', 'div2', 'div17']
# Is Leaf:  True
#
# Block Content:  <div18>Brad Lidge<span>†*<span>00%–1st</span></span></div18>
# Block Path:  ['div', 'div2', 'div18']
# Is Leaf:  True
#
# Block Content:  <div19>Kevin Millwood<span>†*<span>00%–1st</span></span></div19>
# Block Path:  ['div', 'div2', 'div19']
# Is Leaf:  True
#
# Block Content:  <div20>Carlos Zambrano<span>†*<span>00%–1st</span></span></div20>
# Block Path:  ['div', 'div2', 'div20']
# Is Leaf:  True
#
# Block Content:  <div21>Players who were eligible for the first time in 2018 but were <span>not</span> on</div21>
# Block Path:  ['div', 'div2', 'div21']
# Is Leaf:  True
#
# Block Content:  <div22>the ballot included <span>Rod Barajas</span>, <span>Miguel Batista</span>, <span>Geoff Blum</span>, <span>Miguel</span></div22>
# Block Path:  ['div', 'div2', 'div22']
# Is Leaf:  True
#
# Block Content:  <div23>Cairo<span>, <span>Aaron Cook<span>, </span>Francisco Cordero<span>, </span>Juan Cruz<span>, </span>Brian Fuentes<span>,</span></span></span></div23>
# Block Path:  ['div', 'div2', 'div23']
# Is Leaf:  True
#
# Block Content:  <div24>Bill Hall<span>, </span>Willie Harris<span>, </span>Nick Johnson<span>, <span>Adam Kennedy<span>, <span>Rodrigo</span></span></span></span></div24>
# Block Path:  ['div', 'div2', 'div24']
# Is Leaf:  True
#
# Block Content:  <div25>López<span>, </span>Mike MacDougal<span>, </span>Guillermo Mota<span>, </span>Will Ohman<span>, </span>Vicente</div25>
# Block Path:  ['div', 'div2', 'div25']
# Is Leaf:  True
#
# Block Content:  <div26>Padilla<span>, </span>Carl Pavano<span>, </span>Scott Podsednik<span>, </span>Juan Rivera<span>, </span>J. C. Romero<span>,</span></div26>
# Block Path:  ['div', 'div2', 'div26']
# Is Leaf:  True
#
# Block Content:  <div27>Brian Schneider<span>, <span>Ben Sheets</span>, <span>Jeff Suppan</span>, <span>Kip Wells</span>, <span>Dan Wheeler</span></span></div27>
# Block Path:  ['div', 'div2', 'div27']
# Is Leaf:  True
#
# Block Content:  <div28>and <span>Jack Wilson</span>.</div28>
# Block Path:  ['div', 'div2', 'div28']
# Is Leaf:  True
#
# Block Content:  <div29>Scott Rolen's 10.2% was the lowest first-year vote percentage in</div29>
# Block Path:  ['div', 'div2', 'div29']
# Is Leaf:  True
#
# Block Content:  <div30>history for a candidate who was eventually elected by the BBWAA.</div30>
# Block Path:  ['div', 'div2', 'div30']
# Is Leaf:  True
#
# Block Content:  <div31>He was voted in on the <span>2023 ballot</span>.</div31>
# Block Path:  ['div', 'div2', 'div31']
# Is Leaf:  True
#
# Block Content:  <div32>[10]</div32>
# Block Path:  ['div', 'div2', 'div32']
# Is Leaf:  True
#
# Block Content:  <div33>Modern Baseball Era Committee <span>[<span>edit</span>]</span></div33>
# Block Path:  ['div', 'div2', 'div33']
# Is Leaf:  True
#
# Block Content:  <div34>On July 23, 2016, the Hall of Fame announced changes to the Era Committee system. The system's</div34>
# Block Path:  ['div', 'div2', 'div34']
# Is Leaf:  True
#
# Block Content:  <div35>timeframes were restructured to place a greater emphasis on the modern game, and to reduce the</div35>
# Block Path:  ['div', 'div2', 'div35']
# Is Leaf:  True
#
# Block Content:  <div0>Jack Morris</div0>
# Block Path:  ['div', 'div3', 'div0']
# Is Leaf:  True
#
# Block Content:  <div1>Alan Trammell</div1>
# Block Path:  ['div', 'div3', 'div1']
# Is Leaf:  True
#
# Block Content:  <div2>frequency at which individuals from the pre-1970 game (including</div2>
# Block Path:  ['div', 'div3', 'div2']
# Is Leaf:  True
#
# Block Content:  <div3>Negro league baseball<span> figures) will have their careers reviewed.</span></div3>
# Block Path:  ['div', 'div3', 'div3']
# Is Leaf:  True
#
# Block Content:  <div4>[3]</div4>
# Block Path:  ['div', 'div3', 'div4']
# Is Leaf:  True
#
# Block Content:  <div5>Considering candidates whose greatest contributions occurred from</div5>
# Block Path:  ['div', 'div3', 'div5']
# Is Leaf:  True
#
# Block Content:  <div6>1970 to 1987, the Modern Baseball Era Committee met in 2017 as</div6>
# Block Path:  ['div', 'div3', 'div6']
# Is Leaf:  True
#
# Block Content:  <div7>part of the elections for the next calendar year.</div7>
# Block Path:  ['div', 'div3', 'div7']
# Is Leaf:  True
#
# Block Content:  <div8>Further information: <span>Veterans Committee §2016 revisions</span></div8>
# Block Path:  ['div', 'div3', 'div8']
# Is Leaf:  True
#
# Block Content:  <div9>On November 6, 2017, the Hall announced the 10 candidates to be</div9>
# Block Path:  ['div', 'div3', 'div9']
# Is Leaf:  True
#
# Block Content:  <div10>considered when the Modern Baseball Era Committee met at the</div10>
# Block Path:  ['div', 'div3', 'div10']
# Is Leaf:  True
#
# Block Content:  <div11>2017 winter meetings near <span>Walt Disney World<span> on December 10, with</span></span></div11>
# Block Path:  ['div', 'div3', 'div11']
# Is Leaf:  True
#
# Block Content:  <div12>the voting results announced immediately after the committee</div12>
# Block Path:  ['div', 'div3', 'div12']
# Is Leaf:  True
#
# Block Content:  <div13>met.</div13>
# Block Path:  ['div', 'div3', 'div13']
# Is Leaf:  True
#
# Block Content:  <div14>[11]</div14>
# Block Path:  ['div', 'div3', 'div14']
# Is Leaf:  True
#
# Block Content:  <div15> The cutoff for election and induction remained the standard</div15>
# Block Path:  ['div', 'div3', 'div15']
# Is Leaf:  True
#
# Block Content:  <div16>75%, or 12 of 16 votes.</div16>
# Block Path:  ['div', 'div3', 'div16']
# Is Leaf:  True
#
# Block Content:  <div17>The committee consisted of the following individuals:</div17>
# Block Path:  ['div', 'div3', 'div17']
# Is Leaf:  True
#
# Block Content:  <div18>[4]</div18>
# Block Path:  ['div', 'div3', 'div18']
# Is Leaf:  True
#
# Block Content:  <div19>Hall of Famers: <span>George Brett</span>, <span>Rod Carew<span>, <span>Bobby Cox</span>, <span>Dennis</span></span></span></div19>
# Block Path:  ['div', 'div3', 'div19']
# Is Leaf:  True
#
# Block Content:  <div20>Eckersley<span>, <span>John Schuerholz</span>, <span>Don Sutton</span>, <span>Dave Winfield</span>, <span>Robin</span></span></div20>
# Block Path:  ['div', 'div3', 'div20']
# Is Leaf:  True
#
# Block Content:  <div21>Yount</div21>
# Block Path:  ['div', 'div3', 'div21']
# Is Leaf:  True
#
# Block Content:  <div22>Executives: <span>Sandy Alderson<span>, </span>Paul Beeston<span>, </span>Bob Castellini<span>, </span>David</span></div22>
# Block Path:  ['div', 'div3', 'div22']
# Is Leaf:  True
#
# Block Content:  <div23>Glass<span>, </span>Bill DeWitt</div23>
# Block Path:  ['div', 'div3', 'div23']
# Is Leaf:  True
#
# Block Content:  <div24>Media and historians: <span>Bob Elliott</span>, <span>Steve Hirdt</span>, <span>Jayson Stark</span></div24>
# Block Path:  ['div', 'div3', 'div24']
# Is Leaf:  True
#
# Block Content:  <div25>Non-voting committee chair: Jane Forbes Clark (Hall of Fame</div25>
# Block Path:  ['div', 'div3', 'div25']
# Is Leaf:  True
#
# Block Content:  <div26>chairman)</div26>
# Block Path:  ['div', 'div3', 'div26']
# Is Leaf:  True
#
# Block Content:  <div27>CandidateCategoryVotesPercentRef</div27>
# Block Path:  ['div', 'div3', 'div27']
# Is Leaf:  True
#
# Block Content:  <div28>Jack Morris<span>Player1487.5%</span></div28>
# Block Path:  ['div', 'div3', 'div28']
# Is Leaf:  True
#
# Block Content:  <div29>[12]</div29>
# Block Path:  ['div', 'div3', 'div29']
# Is Leaf:  True
#
# Block Content:  <div30>Alan Trammell<span>Player1381.3%</span></div30>
# Block Path:  ['div', 'div3', 'div30']
# Is Leaf:  True
#
# Block Content:  <div31>[12]</div31>
# Block Path:  ['div', 'div3', 'div31']
# Is Leaf:  True
#
# Block Content:  <div32>Ted Simmons<span>Player1168.8%</span></div32>
# Block Path:  ['div', 'div3', 'div32']
# Is Leaf:  True
#
# Block Content:  <div33>[12]</div33>
# Block Path:  ['div', 'div3', 'div33']
# Is Leaf:  True
#
# Block Content:  <div34>Marvin Miller<span>Executive743.8%</span></div34>
# Block Path:  ['div', 'div3', 'div34']
# Is Leaf:  True
#
# Block Content:  <div35>[12]</div35>
# Block Path:  ['div', 'div3', 'div35']
# Is Leaf:  True
#
# Block Content:  <div36>Steve Garvey<span>Player&lt;7–</span></div36>
# Block Path:  ['div', 'div3', 'div36']
# Is Leaf:  True
#
# Block Content:  <div37>[12]</div37>
# Block Path:  ['div', 'div3', 'div37']
# Is Leaf:  True
#
# Block Content:  <div38>Tommy John<span>Player&lt;7–</span></div38>
# Block Path:  ['div', 'div3', 'div38']
# Is Leaf:  True
#
# Block Content:  <div39>[12]</div39>
# Block Path:  ['div', 'div3', 'div39']
# Is Leaf:  True
#
# Block Content:  <div40>Don Mattingly<span>Player&lt;7–</span></div40>
# Block Path:  ['div', 'div3', 'div40']
# Is Leaf:  True
#
# Block Content:  <div41>[12]</div41>
# Block Path:  ['div', 'div3', 'div41']
# Is Leaf:  True
#
# Block Content:  <div42>Dale Murphy<span>Player&lt;7–</span></div42>
# Block Path:  ['div', 'div3', 'div42']
# Is Leaf:  True
#
# Block Content:  <div43>[12]</div43>
# Block Path:  ['div', 'div3', 'div43']
# Is Leaf:  True
#
# Block Content:  <div44>Dave Parker<span>Player&lt;7–</span></div44>
# Block Path:  ['div', 'div3', 'div44']
# Is Leaf:  True
#
# Block Content:  <div45>[12]</div45>
# Block Path:  ['div', 'div3', 'div45']
# Is Leaf:  True
#
# Block Content:  <div46>Luis Tiant<span>Player&lt;7–</span></div46>
# Block Path:  ['div', 'div3', 'div46']
# Is Leaf:  True
#
# Block Content:  <div47>[12]</div47>
# Block Path:  ['div', 'div3', 'div47']
# Is Leaf:  True
#
# Block Content:  <div48>All candidates except Miller were living when the ballot and voting results were announced. Mattingly,</div48>
# Block Path:  ['div', 'div3', 'div48']
# Is Leaf:  True
#
# Block Content:  <div49>Morris, Murphy and Trammell were being considered for the first time; the others had been considered at</div49>
# Block Path:  ['div', 'div3', 'div49']
# Is Leaf:  True
#
# Block Content:  <div0>least once by one of the predecessors to this committee. Garvey, John, Miller, Parker and Simmons were</div0>
# Block Path:  ['div', 'div4', 'div0']
# Is Leaf:  True
#
# Block Content:  <div1>most recently considered in 2014 by the former Expansion Era Committee, and Tiant was most recently</div1>
# Block Path:  ['div', 'div4', 'div1']
# Is Leaf:  True
#
# Block Content:  <div2>considered by the former Golden Era Committee in 2015. Among players, Simmons was the only candidate</div2>
# Block Path:  ['div', 'div4', 'div2']
# Is Leaf:  True
#
# Block Content:  <div3>who was not on the BBWAA ballot for the full 15-year period formerly allowed by Hall rules; he received less</div3>
# Block Path:  ['div', 'div4', 'div3']
# Is Leaf:  True
#
# Block Content:  <div4>than 5% when he debuted on the BBWAA ballot in 1994 and thus did not appear on further ballots. The Hall</div4>
# Block Path:  ['div', 'div4', 'div4']
# Is Leaf:  True
#
# Block Content:  <div5>changed the eligibility period to 10 years starting with the 2015 election, but Trammell and Mattingly (who</div5>
# Block Path:  ['div', 'div4', 'div5']
# Is Leaf:  True
#
# Block Content:  <div6>were then past the new 10-year cutoff) retained their original 15-year eligibility window.</div6>
# Block Path:  ['div', 'div4', 'div6']
# Is Leaf:  True
#
# Block Content:  <div8>The <span>J. G. Taylor Spink Award<span> has been presented by the BBWAA at the annual summer induction</span></span></div8>
# Block Path:  ['div', 'div4', 'div8']
# Is Leaf:  True
#
# Block Content:  <div11> Through 2010, it was awarded during the main induction ceremony, but is now</div11>
# Block Path:  ['div', 'div4', 'div11']
# Is Leaf:  True
#
# Block Content:  <div12>given the previous day at the Hall of Fame Awards Presentation. It recognizes a <span>sportswriter</span> "for meritorious</div12>
# Block Path:  ['div', 'div4', 'div12']
# Is Leaf:  True
#
# Block Content:  <div15> The recipients are not members of the Hall of Fame but are featured in</div15>
# Block Path:  ['div', 'div4', 'div15']
# Is Leaf:  True
#
# Block Content:  <div16>a permanent exhibit at the National Baseball Museum.</div16>
# Block Path:  ['div', 'div4', 'div16']
# Is Leaf:  True
#
# Block Content:  <div17>The three finalists for the 2018 award were announced during the 2017 <span>All-Star<span> break.</span></span></div17>
# Block Path:  ['div', 'div4', 'div17']
# Is Leaf:  True
#
# Block Content:  <div22>Ocker was announced as the recipient during the 2017 winter meetings on December 12.</div22>
# Block Path:  ['div', 'div4', 'div22']
# Is Leaf:  True
#
# Block Content:  <div23>[16]</div23>
# Block Path:  ['div', 'div4', 'div23']
# Is Leaf:  True
#
# Block Content:  <div24> He covered the</div24>
# Block Path:  ['div', 'div4', 'div24']
# Is Leaf:  True
#
# Block Content:  <div25>Cleveland Indians for more than three decades, serving as Cleveland Indians beat reporter for the <span>Beacon-</span></div25>
# Block Path:  ['div', 'div4', 'div25']
# Is Leaf:  True
#
# Block Content:  <div26>Journal<span> from 1981 until his retirement at the end of the 2013 season. Ocker received 168 of the 426 ballots</span></div26>
# Block Path:  ['div', 'div4', 'div26']
# Is Leaf:  True
#
# Block Content:  <div27>cast (including two blanks) to Reeves' 143 and Reusse's 113.</div27>
# Block Path:  ['div', 'div4', 'div27']
# Is Leaf:  True
#
# Block Content:  <div28>[17]</div28>
# Block Path:  ['div', 'div4', 'div28']
# Is Leaf:  True
#
# Block Content:  <div29>Ford C. Frick Award <span>[<span>edit</span>]</span></div29>
# Block Path:  ['div', 'div4', 'div29']
# Is Leaf:  True
#
# Block Content:  <div30>Various changes in July 2016 were also made to the annual <span>Ford C. Frick Award<span> elections, presented</span></span></div30>
# Block Path:  ['div', 'div4', 'div30']
# Is Leaf:  True
#
# Block Content:  <div31>annually to a preeminent baseball broadcaster since 1978. According to the Hall, the new criteria for</div31>
# Block Path:  ['div', 'div4', 'div31']
# Is Leaf:  True
#
# Block Content:  <div32>selection are "Commitment to excellence, quality of broadcasting abilities, reverence within the game,</div32>
# Block Path:  ['div', 'div4', 'div32']
# Is Leaf:  True
#
# Block Content:  <div33>popularity with fans, and recognition by peers."</div33>
# Block Path:  ['div', 'div4', 'div33']
# Is Leaf:  True
#
# Block Content:  <div34>Additionally, a ballot of eight candidates will now be set, down from 10 in years past. The three ballot slots</div34>
# Block Path:  ['div', 'div4', 'div34']
# Is Leaf:  True
#
# Block Content:  <div35>previously determined by fan voting on <span>Facebook</span> will now be filled by a committee of historians.</div35>
# Block Path:  ['div', 'div4', 'div35']
# Is Leaf:  True
#
# Block Content:  <div36>A new election cycle has been established, rotating annually between <span>Current Major League Markets</span> (team-</div36>
# Block Path:  ['div', 'div4', 'div36']
# Is Leaf:  True
#
# Block Content:  <div37>specific announcers) with the 2017 Frick Award; <span>National Voices<span> (broadcasters whose contributions were</span></span></div37>
# Block Path:  ['div', 'div4', 'div37']
# Is Leaf:  True
#
# Block Content:  <div38>realized on a national level) with the 2018 Frick Award; and <span>Broadcasting Beginnings</span> (early team voices and</div38>
# Block Path:  ['div', 'div4', 'div38']
# Is Leaf:  True
#
# Block Content:  <div39>pioneers of baseball broadcasting) with the 2019 Frick Award. This cycle will repeat every three years.</div39>
# Block Path:  ['div', 'div4', 'div39']
# Is Leaf:  True
#
# Block Content:  <div40>[3]</div40>
# Block Path:  ['div', 'div4', 'div40']
# Is Leaf:  True
#
# Block Content:  <div41>The Hall announced the following finalists for the 2018 Ford C. Frick Award on October 23, 2017.</div41>
# Block Path:  ['div', 'div4', 'div41']
# Is Leaf:  True
#
# Block Content:  <div42>[18]</div42>
# Block Path:  ['div', 'div4', 'div42']
# Is Leaf:  True
#
# Block Content:  <div0>Buddy Blattner</div0>
# Block Path:  ['div', 'div5', 'div0']
# Is Leaf:  True
#
# Block Content:  <div1>Joe Buck</div1>
# Block Path:  ['div', 'div5', 'div1']
# Is Leaf:  True
#
# Block Content:  <div2>Bob Costas</div2>
# Block Path:  ['div', 'div5', 'div2']
# Is Leaf:  True
#
# Block Content:  <div5>Al Michaels</div5>
# Block Path:  ['div', 'div5', 'div5']
# Is Leaf:  True
#
# Block Content:  <div6>Joe Morgan</div6>
# Block Path:  ['div', 'div5', 'div6']
# Is Leaf:  True
#
# Block Content:  <div7>Pee Wee Reese</div7>
# Block Path:  ['div', 'div5', 'div7']
# Is Leaf:  True
#
# Block Content:  <div8>Four finalists were members of the Hall of Fame as players—Dean, Drysdale, Morgan and Reese. When the</div8>
# Block Path:  ['div', 'div5', 'div8']
# Is Leaf:  True
#
# Block Content:  <div9>ballot was announced, Buck, Costas, Michaels and Morgan were still alive. The other four were</div9>
# Block Path:  ['div', 'div5', 'div9']
# Is Leaf:  True
#
# Block Content:  <div10>deceased.</div10>
# Block Path:  ['div', 'div5', 'div10']
# Is Leaf:  True
#
# Block Content:  <div11>[18]</div11>
# Block Path:  ['div', 'div5', 'div11']
# Is Leaf:  True
#
# Block Content:  <div12>Costas was announced as the recipient at the 2017 winter meetings on December 13. He began his</div12>
# Block Path:  ['div', 'div5', 'div12']
# Is Leaf:  True
#
# Block Content:  <div13>sportscasting career as a play-by-play caller for the <span>Spirits of St. Louis</span> in the <span>American Basketball</span></div13>
# Block Path:  ['div', 'div5', 'div13']
# Is Leaf:  True
#
# Block Content:  <div14>Association<span>, and went from there to calling </span>NBA<span> and <span>NFL</span> games for <span>CBS</span>, but made his greatest mark as</span></div14>
# Block Path:  ['div', 'div5', 'div14']
# Is Leaf:  True
#
# Block Content:  <div15>part of <span>NBC</span>'s broadcast team for its national MLB telecasts from 1982 to 2009. Costas then joined the <span>MLB</span></div15>
# Block Path:  ['div', 'div5', 'div15']
# Is Leaf:  True
#
# Block Content:  <div16>Network<span>, where he was serving as the network's documentary host when he was announced as the Frick</span></div16>
# Block Path:  ['div', 'div5', 'div16']
# Is Leaf:  True
#
# Block Content:  <div17>Award recipient.</div17>
# Block Path:  ['div', 'div5', 'div17']
# Is Leaf:  True
#
# Block Content:  <div18>[19]</div18>
# Block Path:  ['div', 'div5', 'div18']
# Is Leaf:  True
#
# Block Content:  <div19>References <span>[<span>edit</span>]</span></div19>
# Block Path:  ['div', 'div5', 'div19']
# Is Leaf:  True
#
# Block Content:  <div20>1. ^ </div20>
# Block Path:  ['div', 'div5', 'div20']
# Is Leaf:  True
#
# Block Content:  <div21>a</div21>
# Block Path:  ['div', 'div5', 'div21']
# Is Leaf:  True
#
# Block Content:  <div22>b</div22>
# Block Path:  ['div', 'div5', 'div22']
# Is Leaf:  True
#
# Block Content:  <div23> <span>"Baseball Hall of Fame adds four new members"</span>. <span>ESPN.com</span>. January 24, 2018. Retrieved January 24,</div23>
# Block Path:  ['div', 'div5', 'div23']
# Is Leaf:  True
#
# Block Content:  <div24>2018.</div24>
# Block Path:  ['div', 'div5', 'div24']
# Is Leaf:  True
#
# Block Content:  <div26>and Long-Retired Players"<span> (Press release). National Baseball Hall of Fame and Museum. July 26, 2010.</span></div26>
# Block Path:  ['div', 'div5', 'div26']
# Is Leaf:  True
#
# Block Content:  <span0>"Hall of Fame Makes Series of Announcements"<span> (Press release). National Baseball Hall of Fame and</span></span0>
# Block Path:  ['div', 'div5', 'span0']
# Is Leaf:  True
#
# Block Content:  <span1>"Jack Morris, Alan Trammell Elected to Hall of Fame by Modern Baseball Era Committee"<span> (Press release).</span></span1>
# Block Path:  ['div', 'div5', 'span1']
# Is Leaf:  True
#
# Block Content:  <div37>National Baseball Hall of Fame and Museum. December 10, 2017. Retrieved December 10, 2017.</div37>
# Block Path:  ['div', 'div5', 'div37']
# Is Leaf:  True
#
# Block Content:  <div38>5. <span>^</span> Bloom, Barry J. (December 6, 2016). <span>"Hall of Fame ballots will be made public starting in 2018"<span>. mlb.com.</span></span></div38>
# Block Path:  ['div', 'div5', 'div38']
# Is Leaf:  True
#
# Block Content:  <div39>Retrieved January 18, 2017.</div39>
# Block Path:  ['div', 'div5', 'div39']
# Is Leaf:  True
#
# Block Content:  <div40>6. <span>^</span> Calcaterra, Craig (November 20, 2017). <span>"The Hall of Fame rejected the BBWAA vote to make ballots public"<span>.</span></span></div40>
# Block Path:  ['div', 'div5', 'div40']
# Is Leaf:  True
#
# Block Content:  <div41>NBC Sports. Retrieved December 11, 2017.</div41>
# Block Path:  ['div', 'div5', 'div41']
# Is Leaf:  True
#
# Block Content:  <div42>7. <span>^</span> <span>"Hall of Fame Announces Change to BBWAA Voting Electorate"<span> (Press release). National Baseball Hall of</span></span></div42>
# Block Path:  ['div', 'div5', 'div42']
# Is Leaf:  True
#
# Block Content:  <div43>Fame and Museum. July 28, 2015. Retrieved July 28, 2015.</div43>
# Block Path:  ['div', 'div5', 'div43']
# Is Leaf:  True
#
# Block Content:  <div44>8. <span>^</span> <span>"Ken Griffey Jr. (99 percent of vote), Mike Piazza head to Cooperstown"<span>. espn.go.com. January 6, 2016.</span></span></div44>
# Block Path:  ['div', 'div5', 'div44']
# Is Leaf:  True
#
# Block Content:  <div45>Retrieved January 6, 2016.</div45>
# Block Path:  ['div', 'div5', 'div45']
# Is Leaf:  True
#
# Block Content:  <div46>9. <span>^</span> Baseball Hall of Fame. <span>"BBWAA elects 4 to Hall of Fame"<span>.</span></span></div46>
# Block Path:  ['div', 'div5', 'div46']
# Is Leaf:  True
#
# Block Content:  <div47>10. <span>^</span> Axisa, Mike (January 24, 2022). <span>"2023 Baseball Hall of Fame voting results: Scott Rolen squeaks in, will join</span></div47>
# Block Path:  ['div', 'div5', 'div47']
# Is Leaf:  True
#
# Block Content:  <div48>Fred McGriff in Cooperstown"<span>. <span>CBSSports.com</span>. Retrieved January 24, 2022.</span></div48>
# Block Path:  ['div', 'div5', 'div48']
# Is Leaf:  True
#
# Block Content:  <div0>Privacy policyAbout WikipediaDisclaimersContact WikipediaCode of ConductDevelopersStatisticsCookie statement</div0>
# Block Path:  ['div', 'div6', 'div0']
# Is Leaf:  True
#
# Block Content:  <div1>Mobile view</div1>
# Block Path:  ['div', 'div6', 'div1']
# Is Leaf:  True
#
# Block Content:  <div2>This page was last edited on 3 April 2025, at 20:07(UTC).</div2>
# Block Path:  ['div', 'div6', 'div2']
# Is Leaf:  True
#
# Block Content:  <div3>Text is available under the <span>Creative Commons Attribution-ShareAlike 4.0 License<span>; additional terms may apply. By using this site, you agree to the</span></span></div3>
# Block Path:  ['div', 'div6', 'div3']
# Is Leaf:  True
#
# Block Content:  <div4>Terms of Use<span> and </span>Privacy Policy<span>. Wikipedia® is a registered trademark of the <span>Wikimedia Foundation, Inc.</span>, a non-profit organization.</span></div4>
# Block Path:  ['div', 'div6', 'div4']
# Is Leaf:  True
#
# Block Content:  <div5>Baseball portal</div5>
# Block Path:  ['div', 'div6', 'div5']
# Is Leaf:  True
#
# Block Content:  <div6>[<span>show</span>]<span>V<span> · <span>T<span> · <span>E</span></span></span></span></span></div6>
# Block Path:  ['div', 'div6', 'div6']
# Is Leaf:  True
#
# Block Content:  <div7>[<span>show</span>]<span>V<span> · <span>T<span> · <span>E</span></span></span></span></span></div7>
# Block Path:  ['div', 'div6', 'div7']
# Is Leaf:  True
#
# Block Content:  <div8>11. <span>^</span> <span>"2018 Modern Baseball Era Ballot"</span> (Press release). National Baseball Hall of Fame and Museum. November</div8>
# Block Path:  ['div', 'div6', 'div8']
# Is Leaf:  True
#
# Block Content:  <div9>6, 2017. Retrieved December 2, 2017.</div9>
# Block Path:  ['div', 'div6', 'div9']
# Is Leaf:  True
#
# Block Content:  <div10>12. ^ </div10>
# Block Path:  ['div', 'div6', 'div10']
# Is Leaf:  True
#
# Block Content:  <div11>a</div11>
# Block Path:  ['div', 'div6', 'div11']
# Is Leaf:  True
#
# Block Content:  <div12>b</div12>
# Block Path:  ['div', 'div6', 'div12']
# Is Leaf:  True
#
# Block Content:  <div13>c</div13>
# Block Path:  ['div', 'div6', 'div13']
# Is Leaf:  True
#
# Block Content:  <div14>d</div14>
# Block Path:  ['div', 'div6', 'div14']
# Is Leaf:  True
#
# Block Content:  <div15>e</div15>
# Block Path:  ['div', 'div6', 'div15']
# Is Leaf:  True
#
# Block Content:  <div16>f</div16>
# Block Path:  ['div', 'div6', 'div16']
# Is Leaf:  True
#
# Block Content:  <div17>g</div17>
# Block Path:  ['div', 'div6', 'div17']
# Is Leaf:  True
#
# Block Content:  <div21> Axisa, Mike (December 10, 2017). <span>"Jack Morris and Alan Trammell voted into Hall of Fame by</span></div21>
# Block Path:  ['div', 'div6', 'div21']
# Is Leaf:  True
#
# Block Content:  <div24>14. <span>^</span> <span>"Awards: J. G. Taylor Spink"<span>. National Baseball Hall of Fame and Museum. Retrieved January 11, 2014.</span></span></div24>
# Block Path:  ['div', 'div6', 'div24']
# Is Leaf:  True
#
# Block Content:  <div26>Minneapolis<span>. Retrieved December 2, 2017.</span></div26>
# Block Path:  ['div', 'div6', 'div26']
# Is Leaf:  True
#
# Block Content:  <div31>18. ^ </div31>
# Block Path:  ['div', 'div6', 'div31']
# Is Leaf:  True
#
# Block Content:  <span>"2018 Ford C. Frick Award Ballot"<span> (Press release). National Baseball Hall of Fame and Museum. October</span></span>
# Block Path:  ['div', 'div6', 'span']
# Is Leaf:  True
#
# Block Content:  <div34>23, 2017. Retrieved November 7, 2017.</div34>
# Block Path:  ['div', 'div6', 'div34']
# Is Leaf:  True
#
# Block Content:  <div35>19. <span>^</span> Macklin, Oliver (December 13, 2017). <span>"'National treasure' Costas wins '18 Frick Award"<span>. </span><span>MLB.com<span>. Retrieved</span></span></span></div35>
# Block Path:  ['div', 'div6', 'div35']
# Is Leaf:  True
#
# Block Content:  <div36>December 13, 2017.</div36>
# Block Path:  ['div', 'div6', 'div36']
# Is Leaf:  True
#
# Block Content:  <div39>BBWAA rules for election to the Hall of Fame</div39>
# Block Path:  ['div', 'div6', 'div39']
# Is Leaf:  True
#
# Block Content:  <div40>Balloting for the <span>National Baseball Hall of Fame</span></div40>
# Block Path:  ['div', 'div6', 'div40']
# Is Leaf:  True
#
# Block Content:  <div0>(Redirected from <span>Baseball Hall of Fame balloting, 2018</span>)</div0>
# Block Path:  ['div', 'div0', 'div6', 'div0']
# Is Leaf:  True
#
# Block Content:  <div1>Elections to the <span>National Baseball Hall of Fame</span> for 2018</div1>
# Block Path:  ['div', 'div0', 'div6', 'div1']
# Is Leaf:  True
#
# Block Content:  <div2>proceeded according to rules most recently amended in 2016.</div2>
# Block Path:  ['div', 'div0', 'div6', 'div2']
# Is Leaf:  True
#
# Block Content:  <div3>As in the past, the <span>Baseball Writers' Association of America</span></div3>
# Block Path:  ['div', 'div0', 'div6', 'div3']
# Is Leaf:  True
#
# Block Content:  <div4>(BBWAA) voted by mail to select from a ballot of recently</div4>
# Block Path:  ['div', 'div0', 'div6', 'div4']
# Is Leaf:  True
#
# Block Content:  <div5>retired players. The results were announced on January 24,</div5>
# Block Path:  ['div', 'div0', 'div6', 'div5']
# Is Leaf:  True
#
# Block Content:  <div6>2018, with the BBWAA electing <span>Chipper Jones</span>, <span>Vladimir</span></div6>
# Block Path:  ['div', 'div0', 'div6', 'div6']
# Is Leaf:  True
#
# Block Content:  <div7>Guerrero<span>, </span>Jim Thome<span> and <span>Trevor Hoffman<span> to the Hall of Fame.</span></span></span></div7>
# Block Path:  ['div', 'div0', 'div6', 'div7']
# Is Leaf:  True
#
# Block Content:  <div8>Jones and Thome were elected in their first year of eligibility.</div8>
# Block Path:  ['div', 'div0', 'div6', 'div8']
# Is Leaf:  True
#
# Block Content:  <div9>[1]</div9>
# Block Path:  ['div', 'div0', 'div6', 'div9']
# Is Leaf:  True
#
# Block Content:  <div10>The three voting panels that replaced the more broadly</div10>
# Block Path:  ['div', 'div0', 'div6', 'div10']
# Is Leaf:  True
#
# Block Content:  <div11>defined <span>Veterans Committee<span> following a 2010 rules change</span></span></div11>
# Block Path:  ['div', 'div0', 'div6', 'div11']
# Is Leaf:  True
#
# Block Content:  <div12>[2]</div12>
# Block Path:  ['div', 'div0', 'div6', 'div12']
# Is Leaf:  True
#
# Block Content:  <div13>were replaced by a new set of four panels in 2016.</div13>
# Block Path:  ['div', 'div0', 'div6', 'div13']
# Is Leaf:  True
#
# Block Content:  <div14>[3]</div14>
# Block Path:  ['div', 'div0', 'div6', 'div14']
# Is Leaf:  True
#
# Block Content:  <div15> The</div15>
# Block Path:  ['div', 'div0', 'div6', 'div15']
# Is Leaf:  True
#
# Block Content:  <div16>Modern Baseball Era Committee<span> convened on December 10,</span></div16>
# Block Path:  ['div', 'div0', 'div6', 'div16']
# Is Leaf:  True
#
# Block Content:  <div17>2017, to select from a ballot of retired players and non-playing personnel who made their greatest</div17>
# Block Path:  ['div', 'div0', 'div6', 'div17']
# Is Leaf:  True
#
# Block Content:  <div18>contributions to the sport between 1970 and 1987,</div18>
# Block Path:  ['div', 'div0', 'div6', 'div18']
# Is Leaf:  True
#
# Block Content:  <div19>[3]</div19>
# Block Path:  ['div', 'div0', 'div6', 'div19']
# Is Leaf:  True
#
# Block Content:  <div20> with <span>Jack Morris</span> and <span>Alan Trammell<span> elected by this</span></span></div20>
# Block Path:  ['div', 'div0', 'div6', 'div20']
# Is Leaf:  True
#
# Block Content:  <div21>body.</div21>
# Block Path:  ['div', 'div0', 'div6', 'div21']
# Is Leaf:  True
#
# Block Content:  <div22>[4]</div22>
# Block Path:  ['div', 'div0', 'div6', 'div22']
# Is Leaf:  True
#
# Block Content:  <div23> The formal induction ceremony was held at the Hall's facilities in <span>Cooperstown, New York<span>, on July</span></span></div23>
# Block Path:  ['div', 'div0', 'div6', 'div23']
# Is Leaf:  True
#
# Block Content:  <div24>29, 2018.</div24>
# Block Path:  ['div', 'div0', 'div6', 'div24']
# Is Leaf:  True
#
# Block Content:  <div25>[1]</div25>
# Block Path:  ['div', 'div0', 'div6', 'div25']
# Is Leaf:  True
#
# Block Content:  <div26>BBWAA election <span>[<span>edit</span>]</span></div26>
# Block Path:  ['div', 'div0', 'div6', 'div26']
# Is Leaf:  True
#
# Block Content:  <div27>The BBWAA election rules remained identical to</div27>
# Block Path:  ['div', 'div0', 'div6', 'div27']
# Is Leaf:  True
#
# Block Content:  <div28>those that were in effect for the most recent</div28>
# Block Path:  ['div', 'div0', 'div6', 'div28']
# Is Leaf:  True
#
# Block Content:  <div29>elections. The BBWAA voted at the 2016 winter</div29>
# Block Path:  ['div', 'div0', 'div6', 'div29']
# Is Leaf:  True
#
# Block Content:  <div30>meetings to make all Hall of Fame ballots public</div30>
# Block Path:  ['div', 'div0', 'div6', 'div30']
# Is Leaf:  True
#
# Block Content:  <div31>one week after the results were announced,</div31>
# Block Path:  ['div', 'div0', 'div6', 'div31']
# Is Leaf:  True
#
# Block Content:  <div32>effective with this election.</div32>
# Block Path:  ['div', 'div0', 'div6', 'div32']
# Is Leaf:  True
#
# Block Content:  <div33>[5]</div33>
# Block Path:  ['div', 'div0', 'div6', 'div33']
# Is Leaf:  True
#
# Block Content:  <div34> However, the Hall</div34>
# Block Path:  ['div', 'div0', 'div6', 'div34']
# Is Leaf:  True
#
# Block Content:  <div35>rejected the BBWAA's proposal, and ballots remain</div35>
# Block Path:  ['div', 'div0', 'div6', 'div35']
# Is Leaf:  True
#
# Block Content:  <div36>confidential unless individual voters choose to</div36>
# Block Path:  ['div', 'div0', 'div6', 'div36']
# Is Leaf:  True
#
# Block Content:  <div37>reveal them (which is allowed by Hall of Fame</div37>
# Block Path:  ['div', 'div0', 'div6', 'div37']
# Is Leaf:  True
#
# Block Content:  <div38>rules).</div38>
# Block Path:  ['div', 'div0', 'div6', 'div38']
# Is Leaf:  True
#
# Block Content:  <div39>[6]</div39>
# Block Path:  ['div', 'div0', 'div6', 'div39']
# Is Leaf:  True
#
# Block Content:  <div40>DonateCreate accountLog in</div40>
# Block Path:  ['div', 'div0', 'div6', 'div40']
# Is Leaf:  True

# %%
ckpt_path = "zstanjj/HTML-Pruner-Phi-3.8B"
if torch.cuda.is_available():
    device="cuda"
else:
    device="cpu"
    
gen_embed_pruner = GenHTMLPruner(gen_model=ckpt_path, device=device)
block_rankings = gen_embed_pruner.calculate_block_rankings(question, pruned_html, block_2)
print(block_rankings)

# [1, 0]

pruned_html = gen_embed_pruner.prune_HTML(pruned_html, block_2, block_rankings, chat_tokenizer, MAX_CONTEXT_WINDOW_GEN)
print(pruned_html)
