# %%
import camelot

pdf_path = "content.pdf"

tables = camelot.read_pdf(pdf_path, pages="all", flavor='lattice')
print(f"Tổng cộng: {tables.n} bảng được tìm thấy.")

table_strings = []

for i, table in enumerate(tables):
    table_str = table.df.to_markdown(index=False)  # Dễ đọc hơn với index=False
    table_strings.append(table_str)
    print(f"\n--- Bảng {i + 1} ---")
    print(table_str)
# Out:
# Tổng cộng: 10 bảng được tìm thấy.
#
# --- Bảng 1 ---
# | 0   | 1                                                 |
# |:----|:--------------------------------------------------|
# |     | Elected to the Hall of Fame on this ballot (named |
# |     | in bold italics).                                 |
# |     | Elected subsequently, as of 2025 (named in plain  |
# |     | italics).                                         |
# |     | Renominated for the 2019 BBWAA election by        |
# |     | adequate performance on this ballot and has not   |
# |     | subsequently been eliminated.                     |
# |     | Eliminated from annual BBWAA consideration by     |
# |     | poor performance or expiration on subsequent      |
#
# --- Bảng 2 ---
# | 0   | 1                                                 |
# |:----|:--------------------------------------------------|
# |     | ballots.                                          |
# |     | Eliminated from annual BBWAA consideration by     |
# |     | poor performance or expiration on this ballot.    |
# | †   | First time on the BBWAA ballot.                   |
# | *   | Eliminated from annual BBWAA consideration by     |
# |     | poor performance on this ballot (not expiration). |
#
# --- Bảng 3 ---
# | 0   | 1             | 2   |
# |:----|:--------------|:----|
# |     |               |     |
# |     |               |     |
# |     |               |     |
# |     |               |     |
# |     | Chipper Jones |     |
#
# --- Bảng 4 ---
# | 0                 | 1     | 2       | 3      | 4    |
# |:------------------|:------|:--------|:-------|:-----|
# | Player            | Votes | Percent | Change | Year |
# | Chipper Jones†    | 410   | 97.2%   | –      | 1st  |
# | Vladimir Guerrero | 392   | 92.9%   | 21.2%  | 2nd  |
# | Jim Thome†        | 379   | 89.8%   | –      | 1st  |
# | Trevor Hoffman    | 337   | 79.9%   | 5.9%   | 3rd  |
# | Edgar Martínez    | 297   | 70.4%   | 11.8%  | 9th  |
# | Mike Mussina      | 268   | 63.5%   | 11.7%  | 5th  |
# | Roger Clemens     | 242   | 57.3%   | 3.2%   | 6th  |
# | Barry Bonds       | 238   | 56.4%   | 2.6%   | 6th  |
# | Curt Schilling    | 216   | 51.2%   | 6.2%   | 6th  |
# | Omar Vizquel†     | 156   | 37.0%   | –      | 1st  |
# | Larry Walker      | 144   | 34.1%   | 12.2%  | 8th  |
# | Fred McGriff      | 98    | 23.2%   | 1.5%   | 9th  |
# | Manny Ramírez     | 93    | 22.0%   | 1.8%   | 2nd  |
# | Jeff Kent         | 61    | 14.5%   | 2.2%   | 5th  |
# | Gary Sheffield    | 47    | 11.1%   | 2.2%   | 4th  |
#
# --- Bảng 5 ---
# | 0                 | 1   | 2   |
# |:------------------|:----|:----|
# | Vladimir Guerrero |     |     |
# |                   |     |     |
# |                   |     |     |
#
# --- Bảng 6 ---
# | 0                    |   1 | 2     | 3    | 4   |
# |:---------------------|----:|:------|:-----|:----|
# | Billy Wagner         |  47 | 11.1% | 0.9% | 3rd |
# | Scott Rolen†         |  43 | 10.2% | –    | 1st |
# | Sammy Sosa           |  33 | 7.8%  | 0.8% | 6th |
# | Andruw Jones†        |  31 | 7.3%  | –    | 1st |
# | Jamie Moyer†*        |  10 | 2.4%  | –    | 1st |
# | Johan Santana†*      |  10 | 2.4%  | –    | 1st |
# | Johnny Damon†*       |   8 | 1.9%  | –    | 1st |
# | Hideki Matsui†*      |   4 | 0.9%  | –    | 1st |
# | Chris Carpenter†*    |   2 | 0.5%  | –    | 1st |
# | Kerry Wood†*         |   2 | 0.5%  | –    | 1st |
# | Liván Hernández†*    |   1 | 0.2%  | –    | 1st |
# | Carlos Lee†*         |   1 | 0.2%  | –    | 1st |
# | Orlando Hudson†*     |   0 | 0%    | –    | 1st |
# | Aubrey Huff†*        |   0 | 0%    | –    | 1st |
# | Jason Isringhausen†* |   0 | 0%    | –    | 1st |
# | Brad Lidge†*         |   0 | 0%    | –    | 1st |
# | Kevin Millwood†*     |   0 | 0%    | –    | 1st |
# | Carlos Zambrano†*    |   0 | 0%    | –    | 1st |
#
# --- Bảng 7 ---
# | 0   | 1         | 2   |
# |:----|:----------|:----|
# |     |           |     |
# |     |           |     |
# |     | Jim Thome |     |
#
# --- Bảng 8 ---
# | 0           | 1   | 2   |
# |:------------|:----|:----|
# | Jack Morris |     |     |
# |             |     |     |
# |             |     |     |
#
# --- Bảng 9 ---
# | 0             | 1         | 2     | 3       | 4    |
# |:--------------|:----------|:------|:--------|:-----|
# | Candidate     | Category  | Votes | Percent | Ref  |
# | Jack Morris   | Player    | 14    | 87.5%   | [12] |
# | Alan Trammell | Player    | 13    | 81.3%   | [12] |
# | Ted Simmons   | Player    | 11    | 68.8%   | [12] |
# | Marvin Miller | Executive | 7     | 43.8%   | [12] |
# | Steve Garvey  | Player    | <7    | –       | [12] |
# | Tommy John    | Player    | <7    | –       | [12] |
# | Don Mattingly | Player    | <7    | –       | [12] |
# | Dale Murphy   | Player    | <7    | –       | [12] |
# | Dave Parker   | Player    | <7    | –       | [12] |
# | Luis Tiant    | Player    | <7    | –       | [12] |
#
# --- Bảng 10 ---
# | 0                                                |
# |:-------------------------------------------------|
# | V · T · E                                        |
# | [show]                                           |
# | Balloting for the National Baseball Hall of Fame |
# | V · T · E                                        |
# | [show]                                           |
# | Baseball Hall of Fame Class of 2018              |

# %%
import requests
import json

def generate_response(prompt):
    """
    Gửi prompt đến Ollama và nhận về một đoạn phản hồi hoàn chỉnh.
    
    Tham số:
        prompt (str): Câu hỏi hoặc yêu cầu bạn muốn gửi đến mô hình.

    Trả về:
        str: Phản hồi hoàn chỉnh từ mô hình.
    """
    full_response = ""
    context = f"""
   You are given a list of table fragments extracted from a PDF document using OCR. Some tables were split across multiple pages and therefore appear as separate fragments in the input.

    Your task is to:
    1. Carefully analyze all table fragments based on:
    - Column count and alignment
    - Content similarity and continuity
    - Semantic meaning and context
    - Position of headers and repeated patterns
    2. Identify which table fragments logically belong to the same original table, regardless of their order in the input.
    - For example: Table 1 may need to be merged with Table 6 even if they are not adjacent.
    3. Merge those fragments into complete tables while preserving:
    - Correct column alignment
    - Logical row ordering (based on data flow)
    - Data integrity — no duplication or omission of any rows
    4. Output only:
    - The original input table fragments exactly as provided
    - The final merged tables constructed **only from the provided input**
    5. Format all output in clean markdown tables.
    6. DO NOT add explanations, summaries, interpretations, or generate any new text outside of the tables themselves.
    7. DO NOT infer missing rows, extrapolate values, or fill in gaps using context or assumptions.
    8. If two tables do not logically belong together, leave them as separate tables.

    Important rules:
    - Only use data that appears in the input — do NOT generate new content.
    - Do NOT assume that Table 1 must merge with Table 2 — use structural and semantic analysis instead.
    - Be careful with empty rows, partial headers, or formatting issues.
    - Maintain exact values from the original fragments without modification.
    - Clearly separate each final merged table.
    ### ✅ Example Input

    --- Bảng A ---
    | Player       | Votes | Percent |
    |--------------|-------|---------|
    | Chipper Jones| 410   | 97.2%   |

    --- Bảng B ---
    | Player          | Votes | Percent |
    |------------------|-------|---------|
    | Vladimir Guerrero| 392   | 92.9%   |

    --- Bảng C ---
    | Candidate     | Category | Ref  |
    |---------------|----------|------|
    | Jack Morris   | Player   | [12] |

    ### ✅ Expected Output

    ### Merged Table: A + B
    | Player            | Votes | Percent |
    |-------------------|-------|---------|
    | Chipper Jones     | 410   | 97.2%   |
    | Vladimir Guerrero | 392   | 92.9%   |

    ### Original Table C
    | Candidate     | Category | Ref  |
    |---------------|----------|------|
    | Jack Morris   | Player   | [12] |

    This is just an example. The actual tables may be different.
    Only output the final merged tables and the other original table fragments.
    Here is the full list of table fragments from the input:
    {prompt}
    """
    url = "http://localhost:11434/api/generate"
    payload = {
        "model": "qwen3:latest",
        "prompt": context,
        "stream": True
    }

    with requests.post(url, json=payload, stream=True) as response:
        for line in response.iter_lines():
            if line:
                try:
                    data = json.loads(line)
                    if 'response' in data:
                        chunk = data['response']
                        full_response += chunk
                    if data.get('done', False):
                        break
                except json.JSONDecodeError:
                    continue  

    return full_response.strip()

# %%
all_tables_combined = ""

for i, table in enumerate(tables):
    table_str = table.df.to_markdown(index=False)  
    all_tables_combined += f"\n\n--- Bảng {i + 1} ---\n"
    all_tables_combined += table_str

# %%
print("\n--- Toàn bộ bảng đã gộp ---")
print(all_tables_combined)
# Out:
# --- Toàn bộ bảng đã gộp ---
#
#
# --- Bảng 1 ---
# | 0   | 1                                                 |
# |:----|:--------------------------------------------------|
# |     | Elected to the Hall of Fame on this ballot (named |
# |     | in bold italics).                                 |
# |     | Elected subsequently, as of 2025 (named in plain  |
# |     | italics).                                         |
# |     | Renominated for the 2019 BBWAA election by        |
# |     | adequate performance on this ballot and has not   |
# |     | subsequently been eliminated.                     |
# |     | Eliminated from annual BBWAA consideration by     |
# |     | poor performance or expiration on subsequent      |
#
# --- Bảng 2 ---
# | 0   | 1                                                 |
# |:----|:--------------------------------------------------|
# |     | ballots.                                          |
# |     | Eliminated from annual BBWAA consideration by     |
# |     | poor performance or expiration on this ballot.    |
# | †   | First time on the BBWAA ballot.                   |
# | *   | Eliminated from annual BBWAA consideration by     |
# |     | poor performance on this ballot (not expiration). |
#
# --- Bảng 3 ---
# | 0   | 1             | 2   |
# |:----|:--------------|:----|
# |     |               |     |
# |     |               |     |
# |     |               |     |
# |     |               |     |
# |     | Chipper Jones |     |
#
# --- Bảng 4 ---
# | 0                 | 1     | 2       | 3      | 4    |
# |:------------------|:------|:--------|:-------|:-----|
# | Player            | Votes | Percent | Change | Year |
# | Chipper Jones†    | 410   | 97.2%   | –      | 1st  |
# | Vladimir Guerrero | 392   | 92.9%   | 21.2%  | 2nd  |
# | Jim Thome†        | 379   | 89.8%   | –      | 1st  |
# | Trevor Hoffman    | 337   | 79.9%   | 5.9%   | 3rd  |
# | Edgar Martínez    | 297   | 70.4%   | 11.8%  | 9th  |
# | Mike Mussina      | 268   | 63.5%   | 11.7%  | 5th  |
# | Roger Clemens     | 242   | 57.3%   | 3.2%   | 6th  |
# | Barry Bonds       | 238   | 56.4%   | 2.6%   | 6th  |
# | Curt Schilling    | 216   | 51.2%   | 6.2%   | 6th  |
# | Omar Vizquel†     | 156   | 37.0%   | –      | 1st  |
# | Larry Walker      | 144   | 34.1%   | 12.2%  | 8th  |
# | Fred McGriff      | 98    | 23.2%   | 1.5%   | 9th  |
# | Manny Ramírez     | 93    | 22.0%   | 1.8%   | 2nd  |
# | Jeff Kent         | 61    | 14.5%   | 2.2%   | 5th  |
# | Gary Sheffield    | 47    | 11.1%   | 2.2%   | 4th  |
#
# --- Bảng 5 ---
# | 0                 | 1   | 2   |
# |:------------------|:----|:----|
# | Vladimir Guerrero |     |     |
# |                   |     |     |
# |                   |     |     |
#
# --- Bảng 6 ---
# | 0                    |   1 | 2     | 3    | 4   |
# |:---------------------|----:|:------|:-----|:----|
# | Billy Wagner         |  47 | 11.1% | 0.9% | 3rd |
# | Scott Rolen†         |  43 | 10.2% | –    | 1st |
# | Sammy Sosa           |  33 | 7.8%  | 0.8% | 6th |
# | Andruw Jones†        |  31 | 7.3%  | –    | 1st |
# | Jamie Moyer†*        |  10 | 2.4%  | –    | 1st |
# | Johan Santana†*      |  10 | 2.4%  | –    | 1st |
# | Johnny Damon†*       |   8 | 1.9%  | –    | 1st |
# | Hideki Matsui†*      |   4 | 0.9%  | –    | 1st |
# | Chris Carpenter†*    |   2 | 0.5%  | –    | 1st |
# | Kerry Wood†*         |   2 | 0.5%  | –    | 1st |
# | Liván Hernández†*    |   1 | 0.2%  | –    | 1st |
# | Carlos Lee†*         |   1 | 0.2%  | –    | 1st |
# | Orlando Hudson†*     |   0 | 0%    | –    | 1st |
# | Aubrey Huff†*        |   0 | 0%    | –    | 1st |
# | Jason Isringhausen†* |   0 | 0%    | –    | 1st |
# | Brad Lidge†*         |   0 | 0%    | –    | 1st |
# | Kevin Millwood†*     |   0 | 0%    | –    | 1st |
# | Carlos Zambrano†*    |   0 | 0%    | –    | 1st |
#
# --- Bảng 7 ---
# | 0   | 1         | 2   |
# |:----|:----------|:----|
# |     |           |     |
# |     |           |     |
# |     | Jim Thome |     |
#
# --- Bảng 8 ---
# | 0           | 1   | 2   |
# |:------------|:----|:----|
# | Jack Morris |     |     |
# |             |     |     |
# |             |     |     |
#
# --- Bảng 9 ---
# | 0             | 1         | 2     | 3       | 4    |
# |:--------------|:----------|:------|:--------|:-----|
# | Candidate     | Category  | Votes | Percent | Ref  |
# | Jack Morris   | Player    | 14    | 87.5%   | [12] |
# | Alan Trammell | Player    | 13    | 81.3%   | [12] |
# | Ted Simmons   | Player    | 11    | 68.8%   | [12] |
# | Marvin Miller | Executive | 7     | 43.8%   | [12] |
# | Steve Garvey  | Player    | <7    | –       | [12] |
# | Tommy John    | Player    | <7    | –       | [12] |
# | Don Mattingly | Player    | <7    | –       | [12] |
# | Dale Murphy   | Player    | <7    | –       | [12] |
# | Dave Parker   | Player    | <7    | –       | [12] |
# | Luis Tiant    | Player    | <7    | –       | [12] |
#
# --- Bảng 10 ---
# | 0                                                |
# |:-------------------------------------------------|
# | V · T · E                                        |
# | [show]                                           |
# | Balloting for the National Baseball Hall of Fame |
# | V · T · E                                        |
# | [show]                                           |
# | Baseball Hall of Fame Class of 2018              |

# %%
if all_tables_combined.strip():
    prompt = all_tables_combined
    print(generate_response(prompt))
# Out:
# <think>
# Okay, let's tackle this problem step by step. First, I need to understand what's being asked. The user provided several table fragments from a PDF, and my task is to merge them into complete tables if they logically belong together. The key points are to analyze column counts, alignment, content continuity, semantic meaning, and header positions. I need to make sure not to add any new data or assumptions, just work with what's given.
#
# Looking at the tables provided, let's start by examining each one individually to see their structure and content.
#
# Starting with Bảng 1: It has two columns, labeled 0 and 1. The rows under column 0 seem to be empty, while column 1 has text about being elected to the Hall of Fame, eliminated, etc. This looks like a description or notes section, possibly explaining the status of candidates.
#
# Bảng 2: Also has two columns, 0 and 1. The content here continues the text from Bảng 1, mentioning ballots and elimination reasons. The symbols like † and * might indicate notes or annotations. Since the content seems to continue from Bảng 1, maybe they are part of the same table.
#
# Bảng 3: Three columns: 0, 1, 2. Column 0 is empty, column 1 has "Chipper Jones" in one row. This might be a list of players, but only one entry is present. It could be part of a larger table, but with only one row, it's unclear yet.
#
# Bảng 4: This table has five columns: 0 (Player), 1 (Votes), 2 (Percent), 3 (Change), 4 (Year). It lists several players with their votes, percentages, and other details. This seems like the main data table, but there are entries like "Chipper Jones†" and "Vladimir Guerrero" which might be connected to other tables.
#
# Bảng 5: Three columns, similar to Bảng 3, but with "Vladimir Guerrero" in column 0. This could be part of the same table as Bảng 3, but with more entries. However, Bảng 5 has only two rows with Vladimir Guerrero and empty rows. Maybe it's a fragment of a larger list.
#
# Bảng 6: Four columns: 0 (Player), 1 (Votes), 2 (Percent), 3 (Change), 4 (Year). It lists players like Billy Wagner, Scott Rolen, etc., with similar structure to Bảng 4. This might be a continuation of Bảng 4, but with different players.
#
# Bảng 7: Three columns, similar to Bảng 3 and 5. It has "Jim Thome" in column 0. This could be part of the same list as Bảng 3 and 5, but only one entry here.
#
# Bảng 8: Three columns, with "Jack Morris" in column 0. This might be part of a list similar to Bảng 3, 5, 7, but only one entry.
#
# Bảng 9: Five columns: Candidate, Category, Votes, Percent, Ref. It lists candidates with categories and references. This seems like a separate table, maybe a different category of candidates (executives vs players).
#
# Bảng 10: This has only column 0 with text about the Hall of Fame ballot and class of 2018. It's more like a header or title section, not a data table. So it's probably a standalone table or part of a header, not merged with others.
#
# Now, let's look for patterns. Bảng 4 and Bảng 6 both have similar structures (Player, Votes, Percent, Change, Year) but with different players. Bảng 4 includes Chipper Jones and Vladimir Guerrero, which are also mentioned in Bảng 3 and Bảng 5. Wait, Bảng 3 has "Chipper Jones" in column 1, and Bảng 5 has "Vladimir Guerrero" in column 0. Bảng 4 has both players. Maybe Bảng 3 and 5 are parts of the same list as Bảng 4? But Bảng 4 has more data. Alternatively, Bảng 3 and 5 might be separate tables with partial entries.
#
# Looking at Bảng 1 and Bảng 2: They both have two columns and similar text about being elected or eliminated. Since the content flows from Bảng 1 to Bảng 2, they might be merged. However, the user's example merged tables with similar content, so maybe Bảng 1 and 2 are part of the same table. But the problem is that they are in different structures. Bảng 1 has empty rows and text, while Bảng 2 continues that text. Maybe they are part of the same table, but with different sections.
#
# Bảng 3 has "Chipper Jones" in column 1, and Bảng 4 has "Chipper Jones†" in column 0. If the column headers are different, maybe Bảng 3 is a separate list. But the column headers for Bảng 3 are 0, 1, 2, but the data is only in column 1. So maybe Bảng 3 is a list of players, and Bảng 4 is the main data table with more details. However, Bảng 3's "Chipper Jones" is in column 1, while Bảng 4's "Chipper Jones†" is in column 0. This might be a different structure, but the player's name is present in both. Maybe they are separate tables.
#
# Bảng 5 has "Vladimir Guerrero" in column 0. Bảng 4 has "Vladimir Guerrero" in column 0. So maybe Bảng 4 and Bảng 5 are part of the same table. But Bảng 5 has only one entry, and Bảng 4 has more. However, Bảng 5's column headers are 0, 1, 2, while Bảng 4 has 0 (Player), 1 (Votes), etc. Maybe Bảng 5 is a fragment of the same table as Bảng 4, but with different columns. Wait, Bảng 5 has three columns, but Bảng 4 has five. This might not align.
#
# Bảng 7 has "Jim Thome" in column 0, which is also in Bảng 4. So maybe Bảng 4 and Bảng 7 are related. However, Bảng 7's structure is similar to Bảng 3 and 5, which might be separate.
#
# Bảng 8 has "Jack Morris" in column 0, which is also in Bảng 9. Bảng 9 has a different structure with Candidate, Category, etc. So Bảng 8 might be part of Bảng 9's data? But Bảng 9 has "Jack Morris" under Candidate, which matches Bảng 8's "Jack Morris" in column 0. So maybe Bảng 8 and Bảng 9 are related.
#
# Now, looking at Bảng 9: It has Candidate, Category, Votes, Percent, Ref. The entries include Jack Morris, Alan Trammell, etc. Bảng 8 has "Jack Morris" in column 0. If Bảng 8 is a list of candidates, and Bảng 9 has more details, maybe they are separate tables. But the column headers don't match. Bảng 8 has three columns, Bảng 9 has five. So they might be separate.
#
# Bảng 10 is just a header or title, not a data table. So it's probably standalone.
#
# Putting this together:
#
# - Bảng 1 and Bảng 2: Both have similar text about election status. They might be merged as a single table with two columns, but the content is descriptive. However, since they are separate tables with similar content, maybe they are part of the same table, but with different sections. However, the user's example merged tables with similar content, so maybe Bảng 1 and 2 are merged.
#
# - Bảng 4: This seems like the main data table with players, votes, etc. Bảng 3 and 5 might be separate lists, but Bảng 4 includes some of those players. However, Bảng 3's "Chipper Jones" and Bảng 5's "Vladimir Guerrero" are in Bảng 4. So maybe Bảng 3 and 5 are fragments of the same table as Bảng 4, but with different columns. However, the structure doesn't match, so they might be separate.
#
# - Bảng 6: Similar structure to Bảng 4, but with different players. So maybe Bảng 4 and Bảng 6 are separate tables.
#
# - Bảng 9: Another table with different structure, listing candidates with categories and references.
#
# - Bảng 8: Might be part of Bảng 9's data, but the structure doesn't match.
#
# - Bảng 7: Similar to Bảng 3 and 5, but with "Jim Thome" which is in Bảng 4. So maybe Bảng 7 is a separate list.
#
# - Bảng 10: Standalone.
#
# So, possible merged tables:
#
# 1. Bảng 1 and Bảng 2: They have similar text and might be merged into a single table with two columns.
#
# 2. Bảng 4: Main data table with players, votes, etc.
#
# 3. Bảng 6: Another data table with players, votes, etc.
#
# 4. Bảng 9: A separate table with candidate details.
#
# 5. Bảng 3, 5, 7, 8: These might be separate lists or part of other tables, but their structures don't align with Bảng 4 or 6. However, Bảng 3 has "Chipper Jones" which is in Bảng 4, so maybe Bảng 3 is part of Bảng 4's data. But the structure is different. Alternatively, Bảng 3, 5, 7, 8 are separate tables with partial entries.
#
# But since the user's example merged tables with similar content, maybe Bảng 3 and 5 are part of the same table as Bảng 4. However, Bảng 3 has only one entry, and Bảng 5 has one entry. Maybe they are separate.
#
# Alternatively, Bảng 3, 5, 7, 8 are separate tables with partial entries. Since they don't have matching column headers or structures, they can't be merged.
#
# So, the final answer would be:
#
# - Bảng 1 and Bảng 2 merged as one table.
#
# - Bảng 4 as a separate table.
#
# - Bảng 6 as another table.
#
# - Bảng 9 as another table.
#
# - Bảng 3, 5, 7, 8, 10 as standalone tables.
#
# But wait, Bảng 1 and Bảng 2 have similar content and structure (two columns, text). So they can be merged. Bảng 4 and 6 have similar structures (five columns) but different players. Bảng 9 has a different structure. Bảng 3, 5, 7, 8 have different structures. Bảng 10 is a header.
#
# So the merged tables would be:
#
# 1. Bảng 1 + Bảng 2
#
# 2. Bảng 4
#
# 3. Bảng 6
#
# 4. Bảng 9
#
# And the rest (Bảng 3, 5, 7, 8, 10) are standalone.
#
# But need to check if any of the other tables can be merged. For example, Bảng 3 has "Chipper Jones" in column 1, and Bảng 4 has "Chipper Jones†" in column 0. Maybe Bảng 3 is a list of players, and Bảng 4 is the main data table. But since the columns don't match, they can't be merged. Similarly, Bảng 5 has "Vladimir Guerrero" which is in Bảng 4. But again, different structures.
#
# Therefore, the final answer includes the merged tables as above, and the rest as standalone.
# </think>
#
# **Merged Tables:**
#
# 1. **Bảng 1 + Bảng 2**
#    - **Columns:** 0 (empty), 1 (text about election/elimination status)
#    - **Content:** Descriptive text about candidates' statuses (e.g., "elected to the Hall of Fame," "eliminated").
#
# 2. **Bảng 4**
#    - **Columns:** Player (0), Votes (1), Percent (2), Change (3), Year (4)
#    - **Content:** Detailed data on players (e.g., "Chipper Jones†", "Vladimir Guerrero").
#
# 3. **Bảng 6**
#    - **Columns:** Player (0), Votes (1), Percent (2), Change (3), Year (4)
#    - **Content:** Additional players (e.g., "Billy Wagner", "Scott Rolen").
#
# 4. **Bảng 9**
#    - **Columns:** Candidate (0), Category (1), Votes (2), Percent (3), Ref (4)
#    - **Content:** Candidates with categories and references (e.g., "Jack Morris", "Alan Trammell").
#
# **Standalone Tables:**
# - **Bảng 3:** List of players (e.g., "Chipper Jones") in column 1.
# - **Bảng 5:** List of players (e.g., "Vladimir Guerrero") in column 0.
# - **Bảng 7:** List of players (e.g., "Jim Thome") in column 0.
# - **Bảng 8:** List of players (e.g., "Jack Morris") in column 0.
# - **Bảng 10:** Header/title about the Hall of Fame ballot.
#
# **Explanation:**
# - **Bảng 1 + Bảng 2** are merged as they share a similar structure and content (descriptive text about candidate statuses).
# - **Bảng 4** and **Bảng 6** are separate due to distinct player entries but similar structures.
# - **Bảng 9** is a standalone table with a different structure (Candidate, Category, etc.).
# - **Bảng 3, 5, 7, 8** are standalone due to mismatched column headers and partial entries.
# - **Bảng 10** is a header/title and not merged with other tables.
